# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import kagglehub
import os
import shutil
import tarfile
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.layers import Dropout, Lambda
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau, CSVLogger
from tensorflow.keras import backend as K
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import load_model
from tensorflow.keras.metrics import Precision, Recall, MeanIoU

# %matplotlib inline
# %load_ext tensorboard

from tensorflow.keras.layers import (
    Input,
    Conv2D,
    Conv2DTranspose,
    MaxPooling2D,
    BatchNormalization,
    Activation,
    concatenate,
    add,
    multiply
)

from sklearn.datasets import *

# %% [markdown]
# ## Mount Google Drive to access preprocessed datasets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Check if a GPU is available for TensorFlow training

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
    print(f"SUCCESS: {len(gpus)} GPU(s) detected!")
    print(f"Device Name: {gpus[0].name}")
else:
    print(" ERROR: No GPU detected. You are running on CPU.")
# Out:
# SUCCESS: 1 GPU(s) detected!
# Device Name: /physical_device:GPU:0

# %% [markdown]
# ## Extract the preprocessed dataset from the ZIP file into the working directory

# %%
import zipfile
import os

# Path to the ZIP file containing the preprocessed dataset
zip_path = "/content/drive/MyDrive/segmentatioImage/processed_unet.zip"

# Directory where the dataset will be extracted
base_path = "/content/processed_unet"

# Create the destination folder if it does not exist
os.makedirs(base_path, exist_ok=True)

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(base_path)

print("Dataset extracted successfully")
# Out:
# Dataset extracted successfully

# %% [markdown]
# ## Display the files and folders extracted in the dataset directory

# %%
print(os.listdir(base_path))
# Out:
# ['images', 'masks']

# %%
IMAGES_DIR = os.path.join("/content/processed_unet/images")
MASKS_DIR = os.path.join("/content/processed_unet/masks")

# %% [markdown]
# ## Prepare and split the dataset into training, validation, and test sets based on patient IDs

# %%
# Split the dataset into training, validation, and test sets based on patient IDs
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import Sequence
import os
import numpy as np

# =========================
# 1. List image and mask files
# =========================

images_list = sorted(os.listdir(IMAGES_DIR))
masks_list = sorted(os.listdir(MASKS_DIR))

# Extract unique patient IDs
patient_ids = sorted(list(set([
    "_".join(img.split("_")[:2])
    for img in images_list
])))

print("Total patients:", len(patient_ids))


# =========================
# 2. Split patients into train, validation, and test sets
# =========================

train_patients, temp_patients = train_test_split(
    patient_ids,
    test_size=0.2,
    random_state=42
)

val_patients, test_patients = train_test_split(
    temp_patients,
    test_size=0.5,
    random_state=42
)

print("Train patients:", len(train_patients))
print("Validation patients:", len(val_patients))
print("Test patients:", len(test_patients))


# =========================
# 3. Create image and mask lists for each split
# =========================

train_images, train_masks = [], []
val_images, val_masks = [], []
test_images, test_masks = [], []

for img_name, mask_name in zip(images_list, masks_list):

    patient_id = "_".join(img_name.split("_")[:2])

    if patient_id in train_patients:
        train_images.append(img_name)
        train_masks.append(mask_name)

    elif patient_id in val_patients:
        val_images.append(img_name)
        val_masks.append(mask_name)

    elif patient_id in test_patients:
        test_images.append(img_name)
        test_masks.append(mask_name)

print("Train images:", len(train_images))
print("Validation images:", len(val_images))
print("Test images:", len(test_images))
# Out:
# Total patients: 800
# Train patients: 640
# Validation patients: 80
# Test patients: 80
# Train images: 37553
# Validation images: 4799
# Test images: 4715

# %% [markdown]
# ## Count the total number of images and segmentation masks in the dataset

# %%
num_images = len(os.listdir(IMAGES_DIR))
num_masks = len(os.listdir(MASKS_DIR))

print(f"Cantidad de imágenes: {num_images}")
print(f"Cantidad de máscaras: {num_masks}")
# Out:
# Cantidad de imágenes: 47067
# Cantidad de máscaras: 47067

# %% [markdown]
# ## Custom data generator for loading and preprocessing brain tumor MRI images and segmentation masks in batches

# %%
class BrainTumorGenerator(Sequence):

    def __init__(
        self,
        image_files,
        mask_files,
        images_dir,
        masks_dir,
        batch_size=16,
        shuffle=True
    ):
        self.image_files = image_files
        self.mask_files = mask_files
        self.images_dir = images_dir
        self.masks_dir = masks_dir
        self.batch_size = batch_size
        self.shuffle = shuffle

        self.indexes = np.arange(len(self.image_files))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.image_files) / self.batch_size))

    def __getitem__(self, index):

        batch_indexes = self.indexes[
            index * self.batch_size:(index + 1) * self.batch_size
        ]

        batch_images = []
        batch_masks = []

        for i in batch_indexes:

            img = np.load(
                os.path.join(self.images_dir, self.image_files[i])
            )

            mask = np.load(
                os.path.join(self.masks_dir, self.mask_files[i])
            )

            # images
            img = img.astype(np.float32) / 255.0

            # multiclass mask
            mask = mask.astype(np.uint8)
            mask[mask == 4] = 3

            # add chanel to the mask
            mask = np.expand_dims(mask, axis=-1)

            batch_images.append(img)
            batch_masks.append(mask)

        X = np.array(batch_images, dtype=np.float32)
        y = np.array(batch_masks, dtype=np.uint8)

        return X, y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %% [markdown]
# # Create data generators for training, validation, and testing datasets

# %%
final_train_generator = BrainTumorGenerator(
    train_images,
    train_masks,
    IMAGES_DIR,
    MASKS_DIR,
    batch_size=16,
    shuffle=True
)

final_val_generator = BrainTumorGenerator(
    val_images,
    val_masks,
    IMAGES_DIR,
    MASKS_DIR,
    batch_size=16,
    shuffle=False
)

test_generator = BrainTumorGenerator(
    test_images,
    test_masks,
    IMAGES_DIR,
    MASKS_DIR,
    batch_size=16,
    shuffle=False
)

# %% [markdown]
# # Define Dice coefficient metric and Dice loss function for multi-class image segmentation

# %%
@tf.keras.utils.register_keras_serializable()
def dice_coef(y_true, y_pred, smooth=1e-7):
    '''
    Dice coefficient for 10 categories. Ignores background pixel label 0
    Pass to model as metric during compile statement
    '''
    y_true_f = K.flatten(K.one_hot(K.cast(y_true, 'int32'), num_classes=4)[...,1:])
    y_pred_f = K.flatten(y_pred[...,1:])
    intersect = K.sum(y_true_f * y_pred_f, axis=-1)
    denom = K.sum(y_true_f + y_pred_f, axis=-1)
    return K.mean((2. * intersect / (denom + smooth)))

@tf.keras.utils.register_keras_serializable()
def dice_coef_loss(y_true, y_pred):
    '''
    Dice loss to minimize. Pass to model as loss during compile statement
    '''
    return 1 - dice_coef(y_true, y_pred)

# %%
import tensorflow as tf

@tf.keras.utils.register_keras_serializable()
def multiclass_tversky_loss(y_true, y_pred, alpha=0.3, beta=0.7, smooth=1e-6):
    # 1. Asegurar que y_true no tenga dimensiones extra y aplicar One-Hot
    # Si y_true ya es [batch, alto, ancho], remueve el tf.squeeze
    if len(y_true.shape) == 4 and y_true.shape[-1] == 1:
        y_true = tf.squeeze(y_true, axis=-1)

    y_true = tf.one_hot(tf.cast(y_true, tf.int32), depth=4)
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    # 2. Excluir el fondo (clase 0) usando slicing si decides mantener esa lógica
    # Tomamos desde el índice 1 hasta el final en el último eje (clases)
    y_true_nobg = y_true[..., 1:]
    y_pred_nobg = y_pred[..., 1:]

    # 3. Definir los ejes espaciales para la suma (alto y ancho)
    # Asumiendo formato [batch, alto, ancho, clases], los ejes espaciales son 1 y 2
    spatial_axes = [1, 2]

    # 4. Calcular TP, FP, FN vectorialmente (mantiene la dimensión del batch y de las clases)
    tp = tf.reduce_sum(y_true_nobg * y_pred_nobg, axis=spatial_axes)
    fp = tf.reduce_sum((1.0 - y_true_nobg) * y_pred_nobg, axis=spatial_axes)
    fn = tf.reduce_sum(y_true_nobg * (1.0 - y_pred_nobg), axis=spatial_axes)

    # 5. Calcular el índice de Tversky
    tversky = (tp + smooth) / (tp + alpha * fp + beta * fn + smooth)

    # 6. Retornar la pérdida: promedio sobre las clases y luego sobre el batch
    # tversky tiene forma [batch, clases_sin_fondo]
    loss_per_class = 1.0 - tversky

    return tf.reduce_mean(loss_per_class)

# %%
@tf.keras.utils.register_keras_serializable()
def mean_iou(y_true, y_pred, smooth=1e-7):

    # Convert predictions from probabilities to labels
    y_pred = tf.argmax(y_pred, axis=-1)

    # Remove last dimension from ground truth
    y_true = tf.squeeze(y_true, axis=-1)

    # Convert to int32
    y_true = tf.cast(y_true, tf.int32)
    y_pred = tf.cast(y_pred, tf.int32)

    iou_scores = []

    # Ignore background class (0)
    for class_id in range(1, 4):

        true_class = tf.equal(y_true, class_id)
        pred_class = tf.equal(y_pred, class_id)

        intersection = tf.reduce_sum(
            tf.cast(true_class & pred_class, tf.float32)
        )

        union = tf.reduce_sum(
            tf.cast(true_class | pred_class, tf.float32)
        )

        iou = (intersection + smooth) / (union + smooth)

        iou_scores.append(iou)

    return tf.reduce_mean(iou_scores)

# %%
import time
from tensorflow.keras.callbacks import Callback

class TrainingTimer(Callback):

    def on_train_begin(self, logs=None):
        self.train_start = time.time()

    def on_train_end(self, logs=None):
        total_time = time.time() - self.train_start

        hours = int(total_time // 3600)
        minutes = int((total_time % 3600) // 60)
        seconds = int(total_time % 60)

        print("\n===== TRAINING TIME =====")
        print(f"Total training time: {hours}h {minutes}m {seconds}s")

timer_callback = TrainingTimer()

# %% [markdown]
# # Define the U-Net model architecture

# %%
def conv_block(input_tensor, num_filters):

    x = Conv2D(num_filters, (3, 3), padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filters, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    return x

def encoder_block(x, num_filters):
    x = conv_block(x, num_filters)
    p = MaxPooling2D((2, 2),strides=(2,2))(x)
    return x, p



def attention_gate(gating_signal, skip_connection, filters):

    theta_x = Conv2D(filters, (1,1), padding='same')(skip_connection)
    phi_g = Conv2D(filters, (1,1), padding='same')(gating_signal)
    add_xg = add([theta_x, phi_g])
    add_xg = Activation('relu')(add_xg)
    psi = Conv2D(1, (1,1), padding='same')(add_xg)
    psi = Activation('sigmoid')(psi)
    attention = multiply([skip_connection, psi])

    return attention


def decoder_block(input_tensor, skip_tensor, num_filters):

    decoder = Conv2DTranspose( num_filters,(2,2),strides=(2,2),padding='same')(input_tensor)
    skip_tensor = attention_gate(decoder,skip_tensor,num_filters )
    decoder = concatenate([decoder, skip_tensor])
    decoder = conv_block(decoder, num_filters)

    return decoder


def get_attention_unet(Kernels,IMG_HEIGHT=128, IMG_WIDTH=128, IMG_CHANNELS=4, N_CLASSES=4):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))


    encoder1, encoder_pool1 = encoder_block(inputs, Kernels)
    encoder2, encoder_pool2 = encoder_block(encoder_pool1, Kernels*2)
    encoder3, encoder_pool3 = encoder_block(encoder_pool2, Kernels*4)
    encoder4, encoder_pool4 = encoder_block(encoder_pool3, Kernels*8)


    center = conv_block(encoder_pool4,Kernels*16)


    decoder3 = decoder_block(center, encoder4, Kernels * 8)
    decoder2 = decoder_block(decoder3, encoder3, Kernels * 4)
    decoder1 = decoder_block(decoder2, encoder2, Kernels * 2)
    decoder0 = decoder_block(decoder1, encoder1, Kernels)


    outputs = Conv2D(N_CLASSES,(1, 1),activation='softmax')(decoder0)


    model = Model(inputs=[inputs],outputs=[outputs])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=[dice_coef,mean_iou]

    )

    return model

# %%
model = get_attention_unet(Kernels=16)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 128, 128,  │        592 │ input_layer_1[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │      2,320 │ activation_26[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_32[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 64, 64,    │          0 │ activation_27[0]… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 64, 64,    │      4,640 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_33[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 64, 64,    │      9,248 │ activation_28[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_34[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 32, 32,    │          0 │ activation_29[0]… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 32, 32,    │     18,496 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_35[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 32, 32,    │     36,928 │ activation_30[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_36[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 16, 16,    │          0 │ activation_31[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 16, 16,    │     73,856 │ max_pooling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 16, 16,    │    147,584 │ activation_32[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 8, 8, 128) │          0 │ activation_33[0]… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 8, 8, 256) │    295,168 │ max_pooling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ activation_34[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 16, 16,    │    131,200 │ activation_35[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 16, 16,    │     16,512 │ activation_33[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 16, 16,    │     16,512 │ conv2d_transpose… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 16, 16,    │          0 │ conv2d_41[0][0],  │
# │                     │ 128)              │            │ conv2d_42[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 16, 16,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 16, 16, 1) │        129 │ activation_36[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 16, 16, 1) │          0 │ conv2d_43[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 16, 16,    │          0 │ activation_33[0]… │
# │ (Multiply)          │ 128)              │            │ activation_37[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 16, 16,    │    295,040 │ concatenate_4[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 16, 16,    │    147,584 │ activation_38[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_45[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_5  │ (None, 32, 32,    │     32,832 │ activation_39[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 32, 32,    │      4,160 │ activation_31[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 32, 32,    │      4,160 │ conv2d_transpose… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 32, 32,    │          0 │ conv2d_46[0][0],  │
# │                     │ 64)               │            │ conv2d_47[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 32, 32,    │          0 │ add_5[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 32, 32, 1) │         65 │ activation_40[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 32, 32, 1) │          0 │ conv2d_48[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 32, 32,    │          0 │ activation_31[0]… │
# │ (Multiply)          │ 64)               │            │ activation_41[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ multiply_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 32, 32,    │     73,792 │ concatenate_5[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_49[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 32, 32,    │     36,928 │ activation_42[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_50[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 64, 64,    │      8,224 │ activation_43[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 64, 64,    │      1,056 │ activation_29[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 64, 64,    │      1,056 │ conv2d_transpose… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 64, 64,    │          0 │ conv2d_51[0][0],  │
# │                     │ 32)               │            │ conv2d_52[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (None, 64, 64,    │          0 │ add_6[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 64, 64, 1) │         33 │ activation_44[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (None, 64, 64, 1) │          0 │ conv2d_53[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 64, 64,    │          0 │ activation_29[0]… │
# │ (Multiply)          │ 32)               │            │ activation_45[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ multiply_6[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 64, 64,    │     18,464 │ concatenate_6[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_54[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 64, 64,    │      9,248 │ activation_46[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_55[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 128, 128,  │      2,064 │ activation_47[0]… │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 128, 128,  │        272 │ activation_27[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 128, 128,  │        272 │ conv2d_transpose… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 128, 128,  │          0 │ conv2d_56[0][0],  │
# │                     │ 16)               │            │ conv2d_57[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_48       │ (None, 128, 128,  │          0 │ add_7[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 128, 128,  │         17 │ activation_48[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_49       │ (None, 128, 128,  │          0 │ conv2d_58[0][0]   │
# │ (Activation)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 128, 128,  │          0 │ activation_27[0]… │
# │ (Multiply)          │ 16)               │            │ activation_49[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ multiply_7[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 128, 128,  │      4,624 │ concatenate_7[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_59[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_50       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_60 (Conv2D)  │ (None, 128, 128,  │      2,320 │ activation_50[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_60[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_61 (Conv2D)  │ (None, 128, 128,  │         68 │ activation_51[0]… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,991,432 (7.60 MB)
#  Trainable params: 1,988,488 (7.59 MB)
#  Non-trainable params: 2,944 (11.50 KB)

# %% [markdown]
# ## Cross Valitation

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=2,shuffle=True,random_state=42)

filter_options = [16,32]


best_mean_dice = -1

best_filters = None

for filters in filter_options:

    fold_no = 1

    train_dice_scores,train_Iou_scores,val_dice_scores = [],[],[]
    val_Iou_scores,train_loss,val_loss = [],[],[]


    for train_idx, val_idx in kf.split(train_patients):

        print(f"\n========== FOLD {fold_no} ==========")

        # ======================================
        # PATIENT SPLIT
        # ======================================

        fold_train_patients = [train_patients[i] for i in train_idx]

        fold_val_patients = [train_patients[i] for i in val_idx]

        # ======================================
        # IMAGE/MASK LISTS
        # ======================================

        fold_train_images = []
        fold_train_masks = []

        fold_val_images = []
        fold_val_masks = []

        for img_name, mask_name in zip(images_list,masks_list):

            patient_id = "_".join(img_name.split("_")[:2])

            if patient_id in fold_train_patients:

                fold_train_images.append(img_name)
                fold_train_masks.append(mask_name)

            elif patient_id in fold_val_patients:

                fold_val_images.append(img_name)
                fold_val_masks.append(mask_name)


        fold_train_generator = BrainTumorGenerator(
            fold_train_images,
            fold_train_masks,
            IMAGES_DIR,
            MASKS_DIR,
            batch_size=16,
            shuffle=True
        )

        fold_val_generator = BrainTumorGenerator(
            fold_val_images,
            fold_val_masks,
            IMAGES_DIR,
            MASKS_DIR,
            batch_size=16,
            shuffle=False
        )

        # ======================================
        # MODEL
        # ======================================

        model = get_attention_unet(filters)


        # ======================================
        # CALLBACKS
        # ======================================

        earlystopper = EarlyStopping(
            monitor='val_dice_coef',
            mode='max',
            patience=5,
            verbose=1,
            restore_best_weights=True)


        reduce_lr = ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=3,
            min_lr=1e-7,
            verbose=1)

        # ======================================
        # TRAIN
        # ======================================

        history = model.fit(
            fold_train_generator,
            validation_data=fold_val_generator,
            epochs=4,
            callbacks=[
                earlystopper,
                reduce_lr
            ]
        )

        # ======================================
        # EVALUATE
        # ======================================

        scores_train = model.evaluate(fold_train_generator )
        scores_val = model.evaluate(fold_val_generator)

        train_loss.append(scores_train[0])
        train_dice_scores.append(scores_train[1])
        current_dice = scores_val[1]
        train_Iou_scores.append(scores_train[2])

        val_loss.append(scores_val[0])
        val_dice_scores.append(scores_val[1])
        val_Iou_scores.append(scores_val[2])


        fold_no += 1

    mean_dice = np.mean(val_dice_scores)

    if mean_dice > best_mean_dice:
      best_mean_dice = mean_dice
      best_filters = filters
# Out:
# ========== FOLD 1 ==========
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 142s 88ms/step - dice_coef: 0.3799 - loss: 0.1115 - mean_iou: 0.3936 - val_dice_coef: 0.4839 - val_loss: 0.0469 - val_mean_iou: 0.4039 - learning_rate: 0.0010
# Epoch 2/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 77s 65ms/step - dice_coef: 0.6775 - loss: 0.0240 - mean_iou: 0.6271 - val_dice_coef: 0.6419 - val_loss: 0.0267 - val_mean_iou: 0.5322 - learning_rate: 0.0010
# Epoch 3/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 76s 64ms/step - dice_coef: 0.7445 - loss: 0.0188 - mean_iou: 0.6912 - val_dice_coef: 0.6814 - val_loss: 0.0255 - val_mean_iou: 0.5678 - learning_rate: 0.0010
# Epoch 4/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 79s 66ms/step - dice_coef: 0.7784 - loss: 0.0163 - mean_iou: 0.7257 - val_dice_coef: 0.7172 - val_loss: 0.0237 - val_mean_iou: 0.5929 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 4.
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - dice_coef: 0.7975 - loss: 0.0148 - mean_iou: 0.7347
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - dice_coef: 0.7172 - loss: 0.0237 - mean_iou: 0.5929
#
# ========== FOLD 2 ==========
# Epoch 1/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 128s 85ms/step - dice_coef: 0.3269 - loss: 0.1725 - mean_iou: 0.3592 - val_dice_coef: 0.5073 - val_loss: 0.0382 - val_mean_iou: 0.4836 - learning_rate: 0.0010
# Epoch 2/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 75s 64ms/step - dice_coef: 0.6749 - loss: 0.0244 - mean_iou: 0.6322 - val_dice_coef: 0.6277 - val_loss: 0.0296 - val_mean_iou: 0.5161 - learning_rate: 0.0010
# Epoch 3/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 75s 65ms/step - dice_coef: 0.7393 - loss: 0.0193 - mean_iou: 0.6815 - val_dice_coef: 0.6501 - val_loss: 0.0309 - val_mean_iou: 0.5223 - learning_rate: 0.0010
# Epoch 4/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 76s 65ms/step - dice_coef: 0.7751 - loss: 0.0164 - mean_iou: 0.7152 - val_dice_coef: 0.7202 - val_loss: 0.0238 - val_mean_iou: 0.6119 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 4.
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - dice_coef: 0.8105 - loss: 0.0144 - mean_iou: 0.7464
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - dice_coef: 0.7202 - loss: 0.0238 - mean_iou: 0.6119
#
# ========== FOLD 1 ==========
# Epoch 1/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 236s 162ms/step - dice_coef: 0.5026 - loss: 0.0619 - mean_iou: 0.4820 - val_dice_coef: 0.4699 - val_loss: 0.0468 - val_mean_iou: 0.3656 - learning_rate: 0.0010
# Epoch 2/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 161s 136ms/step - dice_coef: 0.7144 - loss: 0.0214 - mean_iou: 0.6586 - val_dice_coef: 0.6917 - val_loss: 0.0259 - val_mean_iou: 0.5713 - learning_rate: 0.0010
# Epoch 3/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 165s 139ms/step - dice_coef: 0.7556 - loss: 0.0180 - mean_iou: 0.7001 - val_dice_coef: 0.7126 - val_loss: 0.0217 - val_mean_iou: 0.5998 - learning_rate: 0.0010
# Epoch 4/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 162s 136ms/step - dice_coef: 0.7853 - loss: 0.0157 - mean_iou: 0.7309 - val_dice_coef: 0.6892 - val_loss: 0.0249 - val_mean_iou: 0.5632 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 3.
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 41s 34ms/step - dice_coef: 0.7788 - loss: 0.0158 - mean_iou: 0.7288
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 38s 32ms/step - dice_coef: 0.7126 - loss: 0.0217 - mean_iou: 0.5998
#
# ========== FOLD 2 ==========
# Epoch 1/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 216s 163ms/step - dice_coef: 0.4463 - loss: 0.0837 - mean_iou: 0.4226 - val_dice_coef: 0.5899 - val_loss: 0.0326 - val_mean_iou: 0.4965 - learning_rate: 0.0010
# Epoch 2/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 160s 138ms/step - dice_coef: 0.6999 - loss: 0.0224 - mean_iou: 0.6358 - val_dice_coef: 0.6754 - val_loss: 0.0250 - val_mean_iou: 0.5674 - learning_rate: 0.0010
# Epoch 3/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 160s 138ms/step - dice_coef: 0.7521 - loss: 0.0183 - mean_iou: 0.6905 - val_dice_coef: 0.6824 - val_loss: 0.0295 - val_mean_iou: 0.5994 - learning_rate: 0.0010
# Epoch 4/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 202s 138ms/step - dice_coef: 0.7818 - loss: 0.0160 - mean_iou: 0.7213 - val_dice_coef: 0.7190 - val_loss: 0.0243 - val_mean_iou: 0.5997 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 4.
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 39s 34ms/step - dice_coef: 0.8016 - loss: 0.0158 - mean_iou: 0.7248
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 39s 33ms/step - dice_coef: 0.7190 - loss: 0.0243 - mean_iou: 0.5997

# %%
print(f"Best filters: {best_filters}")
print(f"Best mean dice: {best_mean_dice}")
# Out:
# Best filters: 16
# Best mean dice: 0.7186514139175415

# %% [markdown]
# # Define training callbacks for early stopping, model checkpointing, learning rate reduction, and training logging

# %%
earlystopper = EarlyStopping(
    monitor='val_dice_coef',
    mode='max',
    patience=5,
    verbose=1,
    restore_best_weights=True
)

checkpointer = ModelCheckpoint(
    'model-best.keras',
    verbose=1,
    save_best_only=True,
    monitor='val_dice_coef',
    mode='max'
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-7,
    verbose=1
)

csv_logger = CSVLogger('training_log.csv')

# %% [markdown]
# # Train the U-Net model using the training and validation generators

# %%
model = get_attention_unet(best_filters)

modeltrain = model.fit(
    final_train_generator,
    validation_data=final_val_generator,
    epochs=30,
    callbacks=[
        earlystopper,
        checkpointer,
        reduce_lr,
        timer_callback
    ]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - dice_coef: 0.2856 - loss: 0.1766 - mean_iou: 0.2767
# Epoch 1: val_dice_coef improved from None to 0.67652, saving model to model-best.keras
#
# Epoch 1: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 172s 58ms/step - dice_coef: 0.4845 - loss: 0.0685 - mean_iou: 0.4517 - val_dice_coef: 0.6765 - val_loss: 0.0238 - val_mean_iou: 0.5937 - learning_rate: 0.0010
# Epoch 2/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - dice_coef: 0.7242 - loss: 0.0206 - mean_iou: 0.6684
# Epoch 2: val_dice_coef did not improve from 0.67652
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 118s 50ms/step - dice_coef: 0.7397 - loss: 0.0194 - mean_iou: 0.6838 - val_dice_coef: 0.6638 - val_loss: 0.0332 - val_mean_iou: 0.5865 - learning_rate: 0.0010
# Epoch 3/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - dice_coef: 0.7765 - loss: 0.0164 - mean_iou: 0.7209
# Epoch 3: val_dice_coef improved from 0.67652 to 0.76185, saving model to model-best.keras
#
# Epoch 3: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 123s 52ms/step - dice_coef: 0.7830 - loss: 0.0160 - mean_iou: 0.7283 - val_dice_coef: 0.7618 - val_loss: 0.0194 - val_mean_iou: 0.6687 - learning_rate: 0.0010
# Epoch 4/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - dice_coef: 0.8065 - loss: 0.0142 - mean_iou: 0.7536
# Epoch 4: val_dice_coef improved from 0.76185 to 0.77370, saving model to model-best.keras
#
# Epoch 4: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 123s 53ms/step - dice_coef: 0.8106 - loss: 0.0138 - mean_iou: 0.7578 - val_dice_coef: 0.7737 - val_loss: 0.0207 - val_mean_iou: 0.6638 - learning_rate: 0.0010
# Epoch 5/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - dice_coef: 0.8244 - loss: 0.0127 - mean_iou: 0.7722
# Epoch 5: val_dice_coef did not improve from 0.77370
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 126s 54ms/step - dice_coef: 0.8277 - loss: 0.0125 - mean_iou: 0.7760 - val_dice_coef: 0.7641 - val_loss: 0.0196 - val_mean_iou: 0.6498 - learning_rate: 0.0010
# Epoch 6/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.8400 - loss: 0.0114 - mean_iou: 0.7905
# Epoch 6: val_dice_coef improved from 0.77370 to 0.78327, saving model to model-best.keras
#
# Epoch 6: finished saving model to model-best.keras
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 126s 54ms/step - dice_coef: 0.8421 - loss: 0.0113 - mean_iou: 0.7925 - val_dice_coef: 0.7833 - val_loss: 0.0196 - val_mean_iou: 0.6732 - learning_rate: 0.0010
# Epoch 7/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - dice_coef: 0.8602 - loss: 0.0098 - mean_iou: 0.8143
# Epoch 7: val_dice_coef did not improve from 0.78327
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 129s 55ms/step - dice_coef: 0.8621 - loss: 0.0097 - mean_iou: 0.8162 - val_dice_coef: 0.7771 - val_loss: 0.0222 - val_mean_iou: 0.6554 - learning_rate: 5.0000e-04
# Epoch 8/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - dice_coef: 0.8686 - loss: 0.0092 - mean_iou: 0.8235
# Epoch 8: val_dice_coef improved from 0.78327 to 0.78494, saving model to model-best.keras
#
# Epoch 8: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 128s 54ms/step - dice_coef: 0.8698 - loss: 0.0092 - mean_iou: 0.8244 - val_dice_coef: 0.7849 - val_loss: 0.0238 - val_mean_iou: 0.6736 - learning_rate: 5.0000e-04
# Epoch 9/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - dice_coef: 0.8739 - loss: 0.0087 - mean_iou: 0.8283
# Epoch 9: val_dice_coef improved from 0.78494 to 0.80112, saving model to model-best.keras
#
# Epoch 9: finished saving model to model-best.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 127s 54ms/step - dice_coef: 0.8747 - loss: 0.0088 - mean_iou: 0.8300 - val_dice_coef: 0.8011 - val_loss: 0.0213 - val_mean_iou: 0.6783 - learning_rate: 5.0000e-04
# Epoch 10/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - dice_coef: 0.8838 - loss: 0.0081 - mean_iou: 0.8419
# Epoch 10: val_dice_coef did not improve from 0.80112
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 128s 54ms/step - dice_coef: 0.8844 - loss: 0.0080 - mean_iou: 0.8418 - val_dice_coef: 0.7985 - val_loss: 0.0233 - val_mean_iou: 0.6762 - learning_rate: 2.5000e-04
# Epoch 11/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - dice_coef: 0.8868 - loss: 0.0078 - mean_iou: 0.8444
# Epoch 11: val_dice_coef did not improve from 0.80112
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 127s 54ms/step - dice_coef: 0.8873 - loss: 0.0078 - mean_iou: 0.8445 - val_dice_coef: 0.7960 - val_loss: 0.0246 - val_mean_iou: 0.6703 - learning_rate: 2.5000e-04
# Epoch 12/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - dice_coef: 0.8907 - loss: 0.0075 - mean_iou: 0.8486
# Epoch 12: val_dice_coef did not improve from 0.80112
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 126s 54ms/step - dice_coef: 0.8905 - loss: 0.0076 - mean_iou: 0.8479 - val_dice_coef: 0.7933 - val_loss: 0.0247 - val_mean_iou: 0.6631 - learning_rate: 2.5000e-04
# Epoch 13/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - dice_coef: 0.8949 - loss: 0.0072 - mean_iou: 0.8544
# Epoch 13: val_dice_coef did not improve from 0.80112
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 126s 54ms/step - dice_coef: 0.8951 - loss: 0.0072 - mean_iou: 0.8541 - val_dice_coef: 0.7937 - val_loss: 0.0260 - val_mean_iou: 0.6600 - learning_rate: 1.2500e-04
# Epoch 14/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - dice_coef: 0.8967 - loss: 0.0071 - mean_iou: 0.8559
# Epoch 14: val_dice_coef did not improve from 0.80112
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 126s 54ms/step - dice_coef: 0.8968 - loss: 0.0071 - mean_iou: 0.8558 - val_dice_coef: 0.7967 - val_loss: 0.0261 - val_mean_iou: 0.6593 - learning_rate: 1.2500e-04
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 9.
#
# ===== TRAINING TIME =====
# Total training time: 0h 30m 4s

# %% [markdown]
# # Evaluate the trained model on the test dataset and display performance metrics

# %%
best_epoch = np.argmax(modeltrain.history['val_dice_coef'])

print(f"Best Epoch: {best_epoch + 1}")

print("\n===== LOSS =====")
print(f"Train Loss: {modeltrain.history['loss'][best_epoch]:.4f}")
print(f"Validation Loss: {modeltrain.history['val_loss'][best_epoch]:.4f}")

print("\n===== DICE =====")
print(f"Train Dice: {modeltrain.history['dice_coef'][best_epoch]:.4f}")
print(f"Validation Dice: {modeltrain.history['val_dice_coef'][best_epoch]:.4f}")

print("\n===== IoU =====")
print(f"Train IoU: {modeltrain.history['mean_iou'][best_epoch]:.4f}")
print(f"Validation IoU: {modeltrain.history['val_mean_iou'][best_epoch]:.4f}")
# Out:
# Best Epoch: 9
#
# ===== LOSS =====
# Train Loss: 0.0088
# Validation Loss: 0.0213
#
# ===== DICE =====
# Train Dice: 0.8747
# Validation Dice: 0.8011
#
# ===== IoU =====
# Train IoU: 0.8300
# Validation IoU: 0.6783

# %% [markdown]
# # Load the best saved model and evaluate its performance on the test dataset

# %%
best_model = load_model(
    'model-best.keras',
    custom_objects={
        'dice_coef': dice_coef
    }
)

# %%
resultstest = best_model.evaluate(test_generator)

for name, value in zip(best_model.metrics_names, resultstest ):
    print(f"{name}: {value:.4f}")
# Out:
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 15s 41ms/step - dice_coef: 0.7872 - loss: 0.0206 - mean_iou: 0.6671
# loss: 0.0206
# compile_metrics: 0.7872

# %% [markdown]
# # Compute multi-class Dice scores and visualize MRI slices with ground truth and predicted tumor segmentations

# %%
def multiclass_dice_score(y_true, y_pred, num_classes=4, smooth=1e-6, include_background=True):
    dice_scores = []

    start_class = 0 if include_background else 1

    for class_id in range(start_class, num_classes):
        y_true_class = (y_true == class_id).astype(np.uint8)
        y_pred_class = (y_pred == class_id).astype(np.uint8)

        intersection = np.sum(y_true_class * y_pred_class)

        dice = (2.0 * intersection + smooth) / (
            np.sum(y_true_class) + np.sum(y_pred_class) + smooth
        )

        dice_scores.append(dice)

    return np.mean(dice_scores), dice_scores


def visualize_slice_80(model, patient_id, slice_num):
    image_name = f"{patient_id}_slice_{slice_num}.npy"

    img = np.load(os.path.join(IMAGES_DIR, image_name))
    img_input = img.astype(np.float32) / 255.0

    true_mask = np.load(os.path.join(MASKS_DIR, image_name)).astype(np.uint8)
    true_mask[true_mask == 4] = 3

    pred_mask = model.predict(
        np.expand_dims(img_input, axis=0),
        verbose=0
    )[0]

    pred_classes = np.argmax(pred_mask, axis=-1).astype(np.uint8)

    dice_mean, dice_per_class = multiclass_dice_score(
        true_mask,
        pred_classes,
        num_classes=4,
        include_background=False
    )

    print("True mask classes:", np.unique(true_mask))
    print("Predicted classes:", np.unique(pred_classes))

    print("Pixels clase 3 reales:",
          np.sum(true_mask == 3))

    print("Pixels clase 3 predichos:",
      np.sum(pred_classes == 3))

    fig, axes = plt.subplots(1, 4, figsize=(20, 5))

    axes[0].imshow(img[:, :, 0], cmap="gray")
    axes[0].imshow(true_mask, cmap="jet", alpha=0.5, vmin=0, vmax=4)
    axes[0].set_title("Overlay Original")
    axes[0].axis("off")

    axes[1].imshow(true_mask, cmap="jet", vmin=0, vmax=4)
    axes[1].set_title("Original Segmentation")
    axes[1].axis("off")

    axes[2].imshow(pred_classes, cmap="jet", vmin=0, vmax=4)
    axes[2].set_title("Predicted Segmentation")
    axes[2].axis("off")

    axes[3].imshow(img[:, :, 0], cmap="gray")
    axes[3].imshow(pred_classes, cmap="jet", alpha=0.5, vmin=0, vmax=4)
    axes[3].set_title(f"Overlay Prediction\nMean Dice: {dice_mean:.4f}")
    axes[3].axis("off")

    plt.tight_layout()
    plt.show()

    print(f"Mean Multiclass Dice: {dice_mean:.4f}")
    print(f"Dice clase 0: {dice_per_class[0]:.4f}")
    print(f"Dice clase 1: {dice_per_class[1]:.4f}")
    print(f"Dice clase 2: {dice_per_class[2]:.4f}")
    #print(f"Dice clase 3: {dice_per_class[3]:.4f}")

# %%
visualize_slice_80(model, "BraTS2021_00020",70)
# Out:
# True mask classes: [0 1 2 3]
# Predicted classes: [0 1 2 3]
# Pixels clase 3 reales: 140
# Pixels clase 3 predichos: 155
# Mean Multiclass Dice: 0.8944
# Dice clase 0: 0.9606
# Dice clase 1: 0.8413
# Dice clase 2: 0.8814
