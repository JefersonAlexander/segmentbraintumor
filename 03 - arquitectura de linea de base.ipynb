# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import kagglehub
import os
import shutil
import tarfile
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.layers import Dropout, Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau, CSVLogger
from tensorflow.keras import backend as K
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import load_model
from tensorflow.keras.metrics import Precision, Recall, MeanIoU

# %matplotlib inline
# %load_ext tensorboard

from sklearn.datasets import *
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import Sequence
import os
import numpy as np

# %% [markdown]
# ## Mount Google Drive to access preprocessed datasets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Check if a GPU is available for TensorFlow training

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
    print(f"SUCCESS: {len(gpus)} GPU(s) detected!")
    print(f"Device Name: {gpus[0].name}")
else:
    print(" ERROR: No GPU detected. You are running on CPU.")
# Out:
# SUCCESS: 1 GPU(s) detected!
# Device Name: /physical_device:GPU:0

# %% [markdown]
# ## Extract the preprocessed dataset from the ZIP file into the working directory

# %%
import zipfile
import os

# Path to the ZIP file containing the preprocessed dataset
zip_path = "/content/drive/MyDrive/segmentatioImage/processed_unet.zip"

# Directory where the dataset will be extracted
base_path = "/content/processed_unet"

# Create the destination folder if it does not exist
os.makedirs(base_path, exist_ok=True)

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(base_path)

print("Dataset extracted successfully")
# Out:
# Dataset extracted successfully

# %% [markdown]
# ## Display the files and folders extracted in the dataset directory

# %%
print(os.listdir(base_path))
# Out:
# ['images', 'masks']

# %%
IMAGES_DIR = os.path.join("/content/processed_unet/images")
MASKS_DIR = os.path.join("/content/processed_unet/masks")

# %% [markdown]
# ## Prepare and split the dataset into training, validation, and test sets based on patient IDs

# %%
images_list = sorted(os.listdir(IMAGES_DIR))
masks_list = sorted(os.listdir(MASKS_DIR))

# Extract unique patient IDs
patient_ids = sorted(list(set([
    "_".join(img.split("_")[:2])
    for img in images_list
])))

print("Total patients:", len(patient_ids))


# =========================
# 2. Split patients into train, validation, and test sets
# =========================

train_patients, temp_patients = train_test_split(
    patient_ids,
    test_size=0.2,
    random_state=42
)

val_patients, test_patients = train_test_split(
    temp_patients,
    test_size=0.5,
    random_state=42
)

print("Train patients:", len(train_patients))
print("Validation patients:", len(val_patients))
print("Test patients:", len(test_patients))


# =========================
# 3. Create image and mask lists for each split
# =========================

train_images, train_masks = [], []
val_images, val_masks = [], []
test_images, test_masks = [], []

for img_name, mask_name in zip(images_list, masks_list):

    patient_id = "_".join(img_name.split("_")[:2])

    if patient_id in train_patients:
        train_images.append(img_name)
        train_masks.append(mask_name)

    elif patient_id in val_patients:
        val_images.append(img_name)
        val_masks.append(mask_name)

    elif patient_id in test_patients:
        test_images.append(img_name)
        test_masks.append(mask_name)

print("Train images:", len(train_images))
print("Validation images:", len(val_images))
print("Test images:", len(test_images))
# Out:
# Total patients: 800
# Train patients: 640
# Validation patients: 80
# Test patients: 80
# Train images: 37553
# Validation images: 4799
# Test images: 4715

# %% [markdown]
# ## Count the total number of images and segmentation masks in the dataset

# %%
num_images = len(os.listdir(IMAGES_DIR))
num_masks = len(os.listdir(MASKS_DIR))

print(f"Cantidad de imágenes: {num_images}")
print(f"Cantidad de máscaras: {num_masks}")
# Out:
# Cantidad de imágenes: 47067
# Cantidad de máscaras: 47067

# %% [markdown]
# ## Custom data generator for loading and preprocessing brain tumor MRI images and segmentation masks in batches

# %%
class BrainTumorGenerator(Sequence):

    def __init__(
        self,
        image_files,
        mask_files,
        images_dir,
        masks_dir,
        batch_size=16,
        shuffle=True
    ):
        self.image_files = image_files
        self.mask_files = mask_files
        self.images_dir = images_dir
        self.masks_dir = masks_dir
        self.batch_size = batch_size
        self.shuffle = shuffle

        self.indexes = np.arange(len(self.image_files))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.image_files) / self.batch_size))

    def __getitem__(self, index):

        batch_indexes = self.indexes[
            index * self.batch_size:(index + 1) * self.batch_size
        ]

        batch_images = []
        batch_masks = []

        for i in batch_indexes:

            img = np.load(
                os.path.join(self.images_dir, self.image_files[i])
            )

            mask = np.load(
                os.path.join(self.masks_dir, self.mask_files[i])
            )

            # images
            img = img.astype(np.float32) / 255.0

            # multiclass mask
            mask = mask.astype(np.uint8)
            mask[mask == 4] = 3

            # add chanel to the mask
            mask = np.expand_dims(mask, axis=-1)

            batch_images.append(img)
            batch_masks.append(mask)

        X = np.array(batch_images, dtype=np.float32)
        y = np.array(batch_masks, dtype=np.uint8)

        return X, y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %% [markdown]
# # Create data generators for training, validation, and testing datasets

# %%
train_generator = BrainTumorGenerator(
    train_images,
    train_masks,
    IMAGES_DIR,
    MASKS_DIR,
    batch_size=16,
    shuffle=True
)

final_val_generator = BrainTumorGenerator(
    val_images,
    val_masks,
    IMAGES_DIR,
    MASKS_DIR,
    batch_size=16,
    shuffle=False
)

test_generator = BrainTumorGenerator(
    test_images,
    test_masks,
    IMAGES_DIR,
    MASKS_DIR,
    batch_size=16,
    shuffle=False
)

# %% [markdown]
# # Define Dice coefficient metric and Dice loss function for multi-class image segmentation

# %%
@tf.keras.utils.register_keras_serializable()
def dice_coef(y_true, y_pred, smooth=1e-7):
    '''
    Dice coefficient for 10 categories. Ignores background pixel label 0
    Pass to model as metric during compile statement
    '''
    y_true_f = K.flatten(K.one_hot(K.cast(y_true, 'int32'), num_classes=4)[...,1:])
    y_pred_f = K.flatten(y_pred[...,1:])
    intersect = K.sum(y_true_f * y_pred_f, axis=-1)
    denom = K.sum(y_true_f + y_pred_f, axis=-1)
    return K.mean((2. * intersect / (denom + smooth)))

@tf.keras.utils.register_keras_serializable()
def dice_coef_9cat_loss(y_true, y_pred):
    '''
    Dice loss to minimize. Pass to model as loss during compile statement
    '''
    return 1 - dice_coef(y_true, y_pred)

# %%
@tf.keras.utils.register_keras_serializable()
def mean_iou(y_true, y_pred, smooth=1e-7):

    # Convert predictions from probabilities to labels
    y_pred = tf.argmax(y_pred, axis=-1)

    # Remove last dimension from ground truth
    y_true = tf.squeeze(y_true, axis=-1)

    # Convert to int32
    y_true = tf.cast(y_true, tf.int32)
    y_pred = tf.cast(y_pred, tf.int32)

    iou_scores = []

    # Ignore background class (0)
    for class_id in range(1, 4):

        true_class = tf.equal(y_true, class_id)
        pred_class = tf.equal(y_pred, class_id)

        intersection = tf.reduce_sum(
            tf.cast(true_class & pred_class, tf.float32)
        )

        union = tf.reduce_sum(
            tf.cast(true_class | pred_class, tf.float32)
        )

        iou = (intersection + smooth) / (union + smooth)

        iou_scores.append(iou)

    return tf.reduce_mean(iou_scores)

# %%
import time
from tensorflow.keras.callbacks import Callback

class TrainingTimer(Callback):

    def on_train_begin(self, logs=None):
        self.train_start = time.time()

    def on_train_end(self, logs=None):
        total_time = time.time() - self.train_start

        hours = int(total_time // 3600)
        minutes = int((total_time % 3600) // 60)
        seconds = int(total_time % 60)

        print("\n===== TRAINING TIME =====")
        print(f"Total training time: {hours}h {minutes}m {seconds}s")

timer_callback = TrainingTimer()

# %% [markdown]
# # Define the U-Net model architecture

# %%
def get_model_UNET(kernels,IMG_HEIGHT=128, IMG_WIDTH=128, IMG_CHANNELS=4, N_CLASSES=4):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))

    c1 = Conv2D(kernels, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(inputs)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(kernels, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(kernels*2, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(kernels*2, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(kernels*4, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(kernels*4, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(kernels*8, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(kernels*8, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D((2, 2))(c4)


    c5 = Conv2D(kernels*16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(kernels*16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c5)

    u6 = Conv2DTranspose(kernels*8, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])


    c6 = Conv2D(kernels*8, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(kernels*8, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = Conv2DTranspose(kernels*4, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(kernels*4, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(kernels*4, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = Conv2DTranspose(kernels*2, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(kernels*2, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(kernels*2, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = Conv2DTranspose(kernels, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(kernels, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(kernels, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(N_CLASSES, (1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=[dice_coef,mean_iou]
    )

    return model

# %%
model = get_model_UNET(kernels=16)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        592 │ input_layer_1[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │      2,320 │ dropout[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │      9,248 │ dropout_1[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │     36,928 │ dropout_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │    147,584 │ dropout_3[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 128) │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8, 256) │    295,168 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 8, 8, 256) │          0 │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8, 256) │    590,080 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │    131,200 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │    295,040 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 16, 16,    │          0 │ conv2d_10[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │    147,584 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │     32,832 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │     73,792 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │     36,928 │ dropout_6[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │      8,224 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64,    │     18,464 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_14[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 64,    │      9,248 │ dropout_7[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │      2,064 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 128, 128,  │      4,624 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_16[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │      2,320 │ dropout_8[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 128, 128,  │         68 │ conv2d_17[0][0]   │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,941,300 (7.41 MB)
#  Trainable params: 1,941,300 (7.41 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Cross Valitation

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=2,shuffle=True,random_state=42)

filter_options = [16,32]


best_mean_dice = -1

best_filters = None

for filters in filter_options:

    fold_no = 1

    train_dice_scores,train_Iou_scores,val_dice_scores = [],[],[]
    val_Iou_scores,train_loss,val_loss = [],[],[]


    for train_idx, val_idx in kf.split(train_patients):

        print(f"\n========== FOLD {fold_no} ==========")

        # ======================================
        # PATIENT SPLIT
        # ======================================

        fold_train_patients = [train_patients[i] for i in train_idx]

        fold_val_patients = [train_patients[i] for i in val_idx]

        # ======================================
        # IMAGE/MASK LISTS
        # ======================================

        fold_train_images = []
        fold_train_masks = []

        fold_val_images = []
        fold_val_masks = []

        for img_name, mask_name in zip(images_list,masks_list):

            patient_id = "_".join(img_name.split("_")[:2])

            if patient_id in fold_train_patients:

                fold_train_images.append(img_name)
                fold_train_masks.append(mask_name)

            elif patient_id in fold_val_patients:

                fold_val_images.append(img_name)
                fold_val_masks.append(mask_name)


        fold_train_generator = BrainTumorGenerator(
            fold_train_images,
            fold_train_masks,
            IMAGES_DIR,
            MASKS_DIR,
            batch_size=16,
            shuffle=True
        )

        fold_val_generator = BrainTumorGenerator(
            fold_val_images,
            fold_val_masks,
            IMAGES_DIR,
            MASKS_DIR,
            batch_size=16,
            shuffle=False
        )

        # ======================================
        # MODEL
        # ======================================

        model = get_model_UNET(filters)


        # ======================================
        # CALLBACKS
        # ======================================

        earlystopper = EarlyStopping(
            monitor='val_dice_coef',
            mode='max',
            patience=5,
            verbose=1,
            restore_best_weights=True)


        reduce_lr = ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=3,
            min_lr=1e-7,
            verbose=1)

        # ======================================
        # TRAIN
        # ======================================

        history = model.fit(
            fold_train_generator,
            validation_data=fold_val_generator,
            epochs=4,
            callbacks=[
                earlystopper,
                reduce_lr
            ]
        )

        # ======================================
        # EVALUATE
        # ======================================

        scores_train = model.evaluate(fold_train_generator )
        scores_val = model.evaluate(fold_val_generator)

        train_loss.append(scores_train[0])
        train_dice_scores.append(scores_train[1])
        current_dice = scores_val[1]
        train_Iou_scores.append(scores_train[2])

        val_loss.append(scores_val[0])
        val_dice_scores.append(scores_val[1])
        val_Iou_scores.append(scores_val[2])


        fold_no += 1

    mean_dice = np.mean(val_dice_scores)

    if mean_dice > best_mean_dice:
      best_mean_dice = mean_dice
      best_filters = filters
# Out:
# ========== FOLD 1 ==========
# Epoch 1/4
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 117s 77ms/step - dice_coef: 0.4480 - loss: 0.0482 - mean_iou: 0.3622 - val_dice_coef: 0.5151 - val_loss: 0.0389 - val_mean_iou: 0.4164 - learning_rate: 0.0010
# Epoch 2/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 65s 55ms/step - dice_coef: 0.6622 - loss: 0.0252 - mean_iou: 0.5929 - val_dice_coef: 0.6443 - val_loss: 0.0280 - val_mean_iou: 0.5171 - learning_rate: 0.0010
# Epoch 3/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 63s 53ms/step - dice_coef: 0.7485 - loss: 0.0188 - mean_iou: 0.6878 - val_dice_coef: 0.6667 - val_loss: 0.0267 - val_mean_iou: 0.5415 - learning_rate: 0.0010
# Epoch 4/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 63s 53ms/step - dice_coef: 0.7823 - loss: 0.0163 - mean_iou: 0.7270 - val_dice_coef: 0.7093 - val_loss: 0.0243 - val_mean_iou: 0.5780 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 4.
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - dice_coef: 0.8031 - loss: 0.0141 - mean_iou: 0.7601
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - dice_coef: 0.7093 - loss: 0.0243 - mean_iou: 0.5780
#
# ========== FOLD 2 ==========
# Epoch 1/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 99s 71ms/step - dice_coef: 0.4604 - loss: 0.0464 - mean_iou: 0.3639 - val_dice_coef: 0.5317 - val_loss: 0.0372 - val_mean_iou: 0.4141 - learning_rate: 0.0010
# Epoch 2/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 63s 54ms/step - dice_coef: 0.6768 - loss: 0.0242 - mean_iou: 0.6029 - val_dice_coef: 0.6474 - val_loss: 0.0298 - val_mean_iou: 0.5259 - learning_rate: 0.0010
# Epoch 3/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 63s 54ms/step - dice_coef: 0.7583 - loss: 0.0182 - mean_iou: 0.6953 - val_dice_coef: 0.7033 - val_loss: 0.0270 - val_mean_iou: 0.5753 - learning_rate: 0.0010
# Epoch 4/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 63s 54ms/step - dice_coef: 0.7854 - loss: 0.0161 - mean_iou: 0.7237 - val_dice_coef: 0.6978 - val_loss: 0.0264 - val_mean_iou: 0.5842 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 3.
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - dice_coef: 0.8036 - loss: 0.0147 - mean_iou: 0.7410
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - dice_coef: 0.7033 - loss: 0.0270 - mean_iou: 0.5753
#
# ========== FOLD 1 ==========
# Epoch 1/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 195s 139ms/step - dice_coef: 0.4372 - loss: 0.0521 - mean_iou: 0.3529 - val_dice_coef: 0.5262 - val_loss: 0.0399 - val_mean_iou: 0.4350 - learning_rate: 0.0010
# Epoch 2/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 135s 114ms/step - dice_coef: 0.6758 - loss: 0.0245 - mean_iou: 0.6091 - val_dice_coef: 0.6972 - val_loss: 0.0245 - val_mean_iou: 0.5720 - learning_rate: 0.0010
# Epoch 3/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 135s 114ms/step - dice_coef: 0.7540 - loss: 0.0186 - mean_iou: 0.6968 - val_dice_coef: 0.7042 - val_loss: 0.0244 - val_mean_iou: 0.5877 - learning_rate: 0.0010
# Epoch 4/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 136s 114ms/step - dice_coef: 0.7784 - loss: 0.0168 - mean_iou: 0.7234 - val_dice_coef: 0.6560 - val_loss: 0.0306 - val_mean_iou: 0.5527 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 3.
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 33s 28ms/step - dice_coef: 0.7936 - loss: 0.0146 - mean_iou: 0.7493
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 31s 27ms/step - dice_coef: 0.7042 - loss: 0.0244 - mean_iou: 0.5877
#
# ========== FOLD 2 ==========
# Epoch 1/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 180s 138ms/step - dice_coef: 0.4430 - loss: 0.0525 - mean_iou: 0.3527 - val_dice_coef: 0.5769 - val_loss: 0.0326 - val_mean_iou: 0.4578 - learning_rate: 0.0010
# Epoch 2/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 134s 115ms/step - dice_coef: 0.6794 - loss: 0.0241 - mean_iou: 0.6057 - val_dice_coef: 0.6459 - val_loss: 0.0291 - val_mean_iou: 0.5500 - learning_rate: 0.0010
# Epoch 3/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 134s 115ms/step - dice_coef: 0.7557 - loss: 0.0184 - mean_iou: 0.6916 - val_dice_coef: 0.6859 - val_loss: 0.0252 - val_mean_iou: 0.5742 - learning_rate: 0.0010
# Epoch 4/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 134s 115ms/step - dice_coef: 0.7849 - loss: 0.0161 - mean_iou: 0.7246 - val_dice_coef: 0.7081 - val_loss: 0.0264 - val_mean_iou: 0.5981 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 4.
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 33s 28ms/step - dice_coef: 0.8022 - loss: 0.0148 - mean_iou: 0.7560
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 32s 27ms/step - dice_coef: 0.7081 - loss: 0.0264 - mean_iou: 0.5981

# %%
print("Best Mean Dice Score:", best_mean_dice)
print("Best Number of Filters:", best_filters)
# Out:
# Best Mean Dice Score: 0.7063015997409821
# Best Number of Filters: 16

# %% [markdown]
# # Define training callbacks for early stopping, model checkpointing, learning rate reduction, and training logging

# %%
earlystopper = EarlyStopping(
    monitor='val_dice_coef',
    mode='max',
    patience=5,
    verbose=1,
    restore_best_weights=True
)

checkpointer = ModelCheckpoint(
    'model-best.keras',
    verbose=1,
    save_best_only=True,
    monitor='val_dice_coef',
    mode='max'
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-7,
    verbose=1
)

csv_logger = CSVLogger('training_log.csv')

# %% [markdown]
# # Train the U-Net model using the training and validation generators

# %%
model=get_model_UNET(best_filters)

modeltrain = model.fit(
    train_generator,
    validation_data=final_val_generator,
    epochs=30,
    callbacks=[
        earlystopper,
        checkpointer,
        reduce_lr,
        timer_callback
    ]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - dice_coef: 0.4324 - loss: 0.0614 - mean_iou: 0.3484
# Epoch 1: val_dice_coef improved from None to 0.68786, saving model to model-best.keras
#
# Epoch 1: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 148s 52ms/step - dice_coef: 0.5665 - loss: 0.0360 - mean_iou: 0.4905 - val_dice_coef: 0.6879 - val_loss: 0.0236 - val_mean_iou: 0.5748 - learning_rate: 0.0010
# Epoch 2/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - dice_coef: 0.7241 - loss: 0.0209 - mean_iou: 0.6626
# Epoch 2: val_dice_coef improved from 0.68786 to 0.72733, saving model to model-best.keras
#
# Epoch 2: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 96s 41ms/step - dice_coef: 0.7355 - loss: 0.0201 - mean_iou: 0.6750 - val_dice_coef: 0.7273 - val_loss: 0.0208 - val_mean_iou: 0.6487 - learning_rate: 0.0010
# Epoch 3/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.7676 - loss: 0.0175 - mean_iou: 0.7095
# Epoch 3: val_dice_coef improved from 0.72733 to 0.74946, saving model to model-best.keras
#
# Epoch 3: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.7740 - loss: 0.0170 - mean_iou: 0.7165 - val_dice_coef: 0.7495 - val_loss: 0.0195 - val_mean_iou: 0.6526 - learning_rate: 0.0010
# Epoch 4/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.7866 - loss: 0.0161 - mean_iou: 0.7309
# Epoch 4: val_dice_coef improved from 0.74946 to 0.76202, saving model to model-best.keras
#
# Epoch 4: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.7893 - loss: 0.0158 - mean_iou: 0.7346 - val_dice_coef: 0.7620 - val_loss: 0.0194 - val_mean_iou: 0.6579 - learning_rate: 0.0010
# Epoch 5/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8024 - loss: 0.0147 - mean_iou: 0.7484
# Epoch 5: val_dice_coef improved from 0.76202 to 0.76454, saving model to model-best.keras
#
# Epoch 5: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8011 - loss: 0.0149 - mean_iou: 0.7473 - val_dice_coef: 0.7645 - val_loss: 0.0182 - val_mean_iou: 0.6532 - learning_rate: 0.0010
# Epoch 6/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8123 - loss: 0.0139 - mean_iou: 0.7608
# Epoch 6: val_dice_coef did not improve from 0.76454
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8112 - loss: 0.0140 - mean_iou: 0.7590 - val_dice_coef: 0.7644 - val_loss: 0.0198 - val_mean_iou: 0.6468 - learning_rate: 0.0010
# Epoch 7/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8142 - loss: 0.0137 - mean_iou: 0.7617
# Epoch 7: val_dice_coef improved from 0.76454 to 0.77515, saving model to model-best.keras
#
# Epoch 7: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8162 - loss: 0.0136 - mean_iou: 0.7644 - val_dice_coef: 0.7752 - val_loss: 0.0197 - val_mean_iou: 0.6791 - learning_rate: 0.0010
# Epoch 8/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8216 - loss: 0.0132 - mean_iou: 0.7707
# Epoch 8: val_dice_coef improved from 0.77515 to 0.77650, saving model to model-best.keras
#
# Epoch 8: finished saving model to model-best.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8210 - loss: 0.0132 - mean_iou: 0.7703 - val_dice_coef: 0.7765 - val_loss: 0.0182 - val_mean_iou: 0.6707 - learning_rate: 0.0010
# Epoch 9/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8383 - loss: 0.0118 - mean_iou: 0.7892
# Epoch 9: val_dice_coef improved from 0.77650 to 0.79019, saving model to model-best.keras
#
# Epoch 9: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8400 - loss: 0.0116 - mean_iou: 0.7910 - val_dice_coef: 0.7902 - val_loss: 0.0184 - val_mean_iou: 0.6779 - learning_rate: 5.0000e-04
# Epoch 10/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8450 - loss: 0.0112 - mean_iou: 0.7967
# Epoch 10: val_dice_coef improved from 0.79019 to 0.79568, saving model to model-best.keras
#
# Epoch 10: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8448 - loss: 0.0112 - mean_iou: 0.7966 - val_dice_coef: 0.7957 - val_loss: 0.0190 - val_mean_iou: 0.6765 - learning_rate: 5.0000e-04
# Epoch 11/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8485 - loss: 0.0109 - mean_iou: 0.8006
# Epoch 11: val_dice_coef did not improve from 0.79568
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8484 - loss: 0.0109 - mean_iou: 0.8005 - val_dice_coef: 0.7911 - val_loss: 0.0185 - val_mean_iou: 0.6782 - learning_rate: 5.0000e-04
# Epoch 12/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8552 - loss: 0.0103 - mean_iou: 0.8082
# Epoch 12: val_dice_coef improved from 0.79568 to 0.79891, saving model to model-best.keras
#
# Epoch 12: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8564 - loss: 0.0102 - mean_iou: 0.8096 - val_dice_coef: 0.7989 - val_loss: 0.0189 - val_mean_iou: 0.6828 - learning_rate: 2.5000e-04
# Epoch 13/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8590 - loss: 0.0100 - mean_iou: 0.8119
# Epoch 13: val_dice_coef did not improve from 0.79891
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8590 - loss: 0.0100 - mean_iou: 0.8118 - val_dice_coef: 0.7973 - val_loss: 0.0190 - val_mean_iou: 0.6792 - learning_rate: 2.5000e-04
# Epoch 14/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8605 - loss: 0.0099 - mean_iou: 0.8135
# Epoch 14: val_dice_coef improved from 0.79891 to 0.79969, saving model to model-best.keras
#
# Epoch 14: finished saving model to model-best.keras
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8609 - loss: 0.0099 - mean_iou: 0.8141 - val_dice_coef: 0.7997 - val_loss: 0.0187 - val_mean_iou: 0.6794 - learning_rate: 2.5000e-04
# Epoch 15/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8645 - loss: 0.0096 - mean_iou: 0.8184
# Epoch 15: val_dice_coef improved from 0.79969 to 0.80242, saving model to model-best.keras
#
# Epoch 15: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8648 - loss: 0.0096 - mean_iou: 0.8185 - val_dice_coef: 0.8024 - val_loss: 0.0190 - val_mean_iou: 0.6754 - learning_rate: 1.2500e-04
# Epoch 16/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8660 - loss: 0.0095 - mean_iou: 0.8192
# Epoch 16: val_dice_coef improved from 0.80242 to 0.80267, saving model to model-best.keras
#
# Epoch 16: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8663 - loss: 0.0095 - mean_iou: 0.8196 - val_dice_coef: 0.8027 - val_loss: 0.0195 - val_mean_iou: 0.6817 - learning_rate: 1.2500e-04
# Epoch 17/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8668 - loss: 0.0094 - mean_iou: 0.8212
# Epoch 17: val_dice_coef did not improve from 0.80267
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8672 - loss: 0.0094 - mean_iou: 0.8211 - val_dice_coef: 0.8026 - val_loss: 0.0206 - val_mean_iou: 0.6861 - learning_rate: 1.2500e-04
# Epoch 18/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8688 - loss: 0.0092 - mean_iou: 0.8225
# Epoch 18: val_dice_coef improved from 0.80267 to 0.80409, saving model to model-best.keras
#
# Epoch 18: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8690 - loss: 0.0092 - mean_iou: 0.8230 - val_dice_coef: 0.8041 - val_loss: 0.0195 - val_mean_iou: 0.6808 - learning_rate: 6.2500e-05
# Epoch 19/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8702 - loss: 0.0091 - mean_iou: 0.8242
# Epoch 19: val_dice_coef improved from 0.80409 to 0.80474, saving model to model-best.keras
#
# Epoch 19: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8697 - loss: 0.0092 - mean_iou: 0.8238 - val_dice_coef: 0.8047 - val_loss: 0.0199 - val_mean_iou: 0.6821 - learning_rate: 6.2500e-05
# Epoch 20/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8702 - loss: 0.0092 - mean_iou: 0.8244
# Epoch 20: val_dice_coef did not improve from 0.80474
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8702 - loss: 0.0092 - mean_iou: 0.8244 - val_dice_coef: 0.8043 - val_loss: 0.0198 - val_mean_iou: 0.6802 - learning_rate: 6.2500e-05
# Epoch 21/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8707 - loss: 0.0091 - mean_iou: 0.8245
# Epoch 21: val_dice_coef improved from 0.80474 to 0.80519, saving model to model-best.keras
#
# Epoch 21: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8711 - loss: 0.0091 - mean_iou: 0.8252 - val_dice_coef: 0.8052 - val_loss: 0.0204 - val_mean_iou: 0.6846 - learning_rate: 3.1250e-05
# Epoch 22/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8718 - loss: 0.0090 - mean_iou: 0.8261
# Epoch 22: val_dice_coef improved from 0.80519 to 0.80545, saving model to model-best.keras
#
# Epoch 22: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8716 - loss: 0.0090 - mean_iou: 0.8259 - val_dice_coef: 0.8054 - val_loss: 0.0199 - val_mean_iou: 0.6858 - learning_rate: 3.1250e-05
# Epoch 23/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8712 - loss: 0.0090 - mean_iou: 0.8250
# Epoch 23: val_dice_coef did not improve from 0.80545
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8717 - loss: 0.0090 - mean_iou: 0.8265 - val_dice_coef: 0.8044 - val_loss: 0.0199 - val_mean_iou: 0.6824 - learning_rate: 3.1250e-05
# Epoch 24/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8725 - loss: 0.0090 - mean_iou: 0.8271
# Epoch 24: val_dice_coef improved from 0.80545 to 0.80588, saving model to model-best.keras
#
# Epoch 24: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 100s 42ms/step - dice_coef: 0.8722 - loss: 0.0090 - mean_iou: 0.8267 - val_dice_coef: 0.8059 - val_loss: 0.0197 - val_mean_iou: 0.6835 - learning_rate: 1.5625e-05
# Epoch 25/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8730 - loss: 0.0090 - mean_iou: 0.8282
# Epoch 25: val_dice_coef did not improve from 0.80588
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 99s 42ms/step - dice_coef: 0.8725 - loss: 0.0090 - mean_iou: 0.8271 - val_dice_coef: 0.8058 - val_loss: 0.0202 - val_mean_iou: 0.6839 - learning_rate: 1.5625e-05
# Epoch 26/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8727 - loss: 0.0090 - mean_iou: 0.8277
# Epoch 26: val_dice_coef did not improve from 0.80588
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8726 - loss: 0.0090 - mean_iou: 0.8273 - val_dice_coef: 0.8057 - val_loss: 0.0198 - val_mean_iou: 0.6825 - learning_rate: 1.5625e-05
# Epoch 27/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8725 - loss: 0.0090 - mean_iou: 0.8278
# Epoch 27: val_dice_coef improved from 0.80588 to 0.80610, saving model to model-best.keras
#
# Epoch 27: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 99s 42ms/step - dice_coef: 0.8726 - loss: 0.0090 - mean_iou: 0.8273 - val_dice_coef: 0.8061 - val_loss: 0.0199 - val_mean_iou: 0.6839 - learning_rate: 7.8125e-06
# Epoch 28/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8737 - loss: 0.0089 - mean_iou: 0.8285
# Epoch 28: val_dice_coef did not improve from 0.80610
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8729 - loss: 0.0089 - mean_iou: 0.8279 - val_dice_coef: 0.8061 - val_loss: 0.0199 - val_mean_iou: 0.6824 - learning_rate: 7.8125e-06
# Epoch 29/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8739 - loss: 0.0089 - mean_iou: 0.8286
# Epoch 29: val_dice_coef did not improve from 0.80610
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8733 - loss: 0.0089 - mean_iou: 0.8279 - val_dice_coef: 0.8058 - val_loss: 0.0198 - val_mean_iou: 0.6838 - learning_rate: 7.8125e-06
# Epoch 30/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8734 - loss: 0.0089 - mean_iou: 0.8287
# Epoch 30: val_dice_coef did not improve from 0.80610
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8732 - loss: 0.0089 - mean_iou: 0.8280 - val_dice_coef: 0.8059 - val_loss: 0.0200 - val_mean_iou: 0.6835 - learning_rate: 3.9063e-06
# Restoring model weights from the end of the best epoch: 27.
#
# ===== TRAINING TIME =====
# Total training time: 0h 49m 38s

# %% [markdown]
# # Evaluate the trained model on the test dataset and display performance metrics

# %%
best_epoch = np.argmax(modeltrain.history['val_dice_coef'])

print(f"Best Epoch: {best_epoch + 1}")

print("\n===== LOSS =====")
print(f"Train Loss: {modeltrain.history['loss'][best_epoch]:.4f}")
print(f"Validation Loss: {modeltrain.history['val_loss'][best_epoch]:.4f}")

print("\n===== DICE =====")
print(f"Train Dice: {modeltrain.history['dice_coef'][best_epoch]:.4f}")
print(f"Validation Dice: {modeltrain.history['val_dice_coef'][best_epoch]:.4f}")

print("\n===== IoU =====")
print(f"Train IoU: {modeltrain.history['mean_iou'][best_epoch]:.4f}")
print(f"Validation IoU: {modeltrain.history['val_mean_iou'][best_epoch]:.4f}")
# Out:
# Best Epoch: 27
#
# ===== LOSS =====
# Train Loss: 0.0090
# Validation Loss: 0.0199
#
# ===== DICE =====
# Train Dice: 0.8726
# Validation Dice: 0.8061
#
# ===== IoU =====
# Train IoU: 0.8273
# Validation IoU: 0.6839

# %% [markdown]
# # Load the best saved model and evaluate its performance on the test dataset

# %%
best_model = load_model(
    'model-best.keras',
    custom_objects={
        'dice_coef': dice_coef
    }
)

# %%
resultstest = best_model.evaluate(test_generator)

for name, value in zip(best_model.metrics_names, resultstest ):
    print(f"{name}: {value:.4f}")
# Out:
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - dice_coef: 0.7963 - loss: 0.0190 - mean_iou: 0.6827
# loss: 0.0190
# compile_metrics: 0.7963

# %% [markdown]
# # Compute multi-class Dice scores and visualize MRI slices with ground truth and predicted tumor segmentations

# %%
def multiclass_dice_score(y_true, y_pred, num_classes=4, smooth=1e-6, include_background=True):
    dice_scores = []

    start_class = 0 if include_background else 1

    for class_id in range(start_class, num_classes):
        y_true_class = (y_true == class_id).astype(np.uint8)
        y_pred_class = (y_pred == class_id).astype(np.uint8)

        intersection = np.sum(y_true_class * y_pred_class)

        dice = (2.0 * intersection + smooth) / (
            np.sum(y_true_class) + np.sum(y_pred_class) + smooth
        )

        dice_scores.append(dice)

    return np.mean(dice_scores), dice_scores


def visualize_slice_80(model, patient_id, slice_num):
    image_name = f"{patient_id}_slice_{slice_num}.npy"

    img = np.load(os.path.join(IMAGES_DIR, image_name))
    img_input = img.astype(np.float32) / 255.0

    true_mask = np.load(os.path.join(MASKS_DIR, image_name)).astype(np.uint8)
    true_mask[true_mask == 4] = 3

    pred_mask = model.predict(
        np.expand_dims(img_input, axis=0),
        verbose=0
    )[0]

    pred_classes = np.argmax(pred_mask, axis=-1).astype(np.uint8)

    dice_mean, dice_per_class = multiclass_dice_score(
        true_mask,
        pred_classes,
        num_classes=4,
        include_background=False
    )

    print("True mask classes:", np.unique(true_mask))
    print("Predicted classes:", np.unique(pred_classes))

    print("Pixels clase 3 reales:",
          np.sum(true_mask == 3))

    print("Pixels clase 3 predichos:",
      np.sum(pred_classes == 3))

    fig, axes = plt.subplots(1, 4, figsize=(20, 5))

    axes[0].imshow(img[:, :, 0], cmap="gray")
    axes[0].imshow(true_mask, cmap="jet", alpha=0.5, vmin=0, vmax=4)
    axes[0].set_title("Overlay Original")
    axes[0].axis("off")

    axes[1].imshow(true_mask, cmap="jet", vmin=0, vmax=4)
    axes[1].set_title("Original Segmentation")
    axes[1].axis("off")

    axes[2].imshow(pred_classes, cmap="jet", vmin=0, vmax=4)
    axes[2].set_title("Predicted Segmentation")
    axes[2].axis("off")

    axes[3].imshow(img[:, :, 0], cmap="gray")
    axes[3].imshow(pred_classes, cmap="jet", alpha=0.5, vmin=0, vmax=4)
    axes[3].set_title(f"Overlay Prediction\nMean Dice: {dice_mean:.4f}")
    axes[3].axis("off")

    plt.tight_layout()
    plt.show()

    print(f"Mean Multiclass Dice: {dice_mean:.4f}")
    print(f"Dice clase 0: {dice_per_class[0]:.4f}")
    print(f"Dice clase 1: {dice_per_class[1]:.4f}")
    print(f"Dice clase 2: {dice_per_class[2]:.4f}")
    #print(f"Dice clase 3: {dice_per_class[3]:.4f}")

# %%
visualize_slice_80(model, "BraTS2021_00020",70)
# Out:
# True mask classes: [0 1 2 3]
# Predicted classes: [0 1 2 3]
# Pixels clase 3 reales: 140
# Pixels clase 3 predichos: 163
# Mean Multiclass Dice: 0.8891
# Dice clase 0: 0.9608
# Dice clase 1: 0.8286
# Dice clase 2: 0.8779
