# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import kagglehub
import os
import shutil
import tarfile
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.layers import Dropout, Lambda
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau, CSVLogger
from tensorflow.keras import backend as K
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import load_model
from tensorflow.keras.metrics import Precision, Recall, MeanIoU

# %matplotlib inline
# %load_ext tensorboard

from tensorflow.keras.layers import (
    Input,
    Conv2D,
    Conv2DTranspose,
    MaxPooling2D,
    BatchNormalization,
    Activation,
    concatenate,
    add,
    multiply
)

from sklearn.datasets import *

# %% [markdown]
# ## Mount Google Drive to access preprocessed datasets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Check if a GPU is available for TensorFlow training

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
    print(f"SUCCESS: {len(gpus)} GPU(s) detected!")
    print(f"Device Name: {gpus[0].name}")
else:
    print(" ERROR: No GPU detected. You are running on CPU.")
# Out:
# SUCCESS: 1 GPU(s) detected!
# Device Name: /physical_device:GPU:0

# %% [markdown]
# ## Extract the preprocessed dataset from the ZIP file into the working directory

# %%
import zipfile
import os

# Path to the ZIP file containing the preprocessed dataset
zip_path = "/content/drive/MyDrive/segmentatioImage/processed_unet.zip"

# Directory where the dataset will be extracted
base_path = "/content/processed_unet"

# Create the destination folder if it does not exist
os.makedirs(base_path, exist_ok=True)

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(base_path)

print("Dataset extracted successfully")
# Out:
# Dataset extracted successfully

# %% [markdown]
# ## Display the files and folders extracted in the dataset directory

# %%
print(os.listdir(base_path))
# Out:
# ['images', 'masks']

# %%
IMAGES_DIR = os.path.join("/content/processed_unet/images")
MASKS_DIR = os.path.join("/content/processed_unet/masks")

# %% [markdown]
# ## Prepare and split the dataset into training, validation, and test sets based on patient IDs

# %%
# Split the dataset into training, validation, and test sets based on patient IDs
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import Sequence
import os
import numpy as np

# =========================
# 1. List image and mask files
# =========================

images_list = sorted(os.listdir(IMAGES_DIR))
masks_list = sorted(os.listdir(MASKS_DIR))

# Extract unique patient IDs
patient_ids = sorted(list(set([
    "_".join(img.split("_")[:2])
    for img in images_list
])))

print("Total patients:", len(patient_ids))


# =========================
# 2. Split patients into train, validation, and test sets
# =========================

train_patients, temp_patients = train_test_split(
    patient_ids,
    test_size=0.2,
    random_state=42
)

val_patients, test_patients = train_test_split(
    temp_patients,
    test_size=0.5,
    random_state=42
)

print("Train patients:", len(train_patients))
print("Validation patients:", len(val_patients))
print("Test patients:", len(test_patients))


# =========================
# 3. Create image and mask lists for each split
# =========================

train_images, train_masks = [], []
val_images, val_masks = [], []
test_images, test_masks = [], []

for img_name, mask_name in zip(images_list, masks_list):

    patient_id = "_".join(img_name.split("_")[:2])

    if patient_id in train_patients:
        train_images.append(img_name)
        train_masks.append(mask_name)

    elif patient_id in val_patients:
        val_images.append(img_name)
        val_masks.append(mask_name)

    elif patient_id in test_patients:
        test_images.append(img_name)
        test_masks.append(mask_name)

print("Train images:", len(train_images))
print("Validation images:", len(val_images))
print("Test images:", len(test_images))
# Out:
# Total patients: 800
# Train patients: 640
# Validation patients: 80
# Test patients: 80
# Train images: 37553
# Validation images: 4799
# Test images: 4715

# %% [markdown]
# ## Count the total number of images and segmentation masks in the dataset

# %%
num_images = len(os.listdir(IMAGES_DIR))
num_masks = len(os.listdir(MASKS_DIR))

print(f"Cantidad de imágenes: {num_images}")
print(f"Cantidad de máscaras: {num_masks}")
# Out:
# Cantidad de imágenes: 47067
# Cantidad de máscaras: 47067

# %% [markdown]
# ## Custom data generator for loading and preprocessing brain tumor MRI images and segmentation masks in batches

# %%
class BrainTumorGenerator(Sequence):

    def __init__(
        self,
        image_files,
        mask_files,
        images_dir,
        masks_dir,
        batch_size=16,
        shuffle=True
    ):
        self.image_files = image_files
        self.mask_files = mask_files
        self.images_dir = images_dir
        self.masks_dir = masks_dir
        self.batch_size = batch_size
        self.shuffle = shuffle

        self.indexes = np.arange(len(self.image_files))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.image_files) / self.batch_size))

    def __getitem__(self, index):

        batch_indexes = self.indexes[
            index * self.batch_size:(index + 1) * self.batch_size
        ]

        batch_images = []
        batch_masks = []

        for i in batch_indexes:

            img = np.load(
                os.path.join(self.images_dir, self.image_files[i])
            )

            mask = np.load(
                os.path.join(self.masks_dir, self.mask_files[i])
            )

            # images
            img = img.astype(np.float32) / 255.0

            # multiclass mask
            mask = mask.astype(np.uint8)
            mask[mask == 4] = 3

            # add chanel to the mask
            mask = np.expand_dims(mask, axis=-1)

            batch_images.append(img)
            batch_masks.append(mask)

        X = np.array(batch_images, dtype=np.float32)
        y = np.array(batch_masks, dtype=np.uint8)

        return X, y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %% [markdown]
# # Create data generators for training, validation, and testing datasets

# %%
final_train_generator = BrainTumorGenerator(
    train_images,
    train_masks,
    IMAGES_DIR,
    MASKS_DIR,
    batch_size=16,
    shuffle=True
)

final_val_generator = BrainTumorGenerator(
    val_images,
    val_masks,
    IMAGES_DIR,
    MASKS_DIR,
    batch_size=16,
    shuffle=False
)

test_generator = BrainTumorGenerator(
    test_images,
    test_masks,
    IMAGES_DIR,
    MASKS_DIR,
    batch_size=16,
    shuffle=False
)

# %% [markdown]
# # Define Dice coefficient metric and Dice loss function for multi-class image segmentation

# %%
@tf.keras.utils.register_keras_serializable()
def dice_coef(y_true, y_pred, smooth=1e-7):
    '''
    Dice coefficient for 10 categories. Ignores background pixel label 0
    Pass to model as metric during compile statement
    '''
    y_true_f = K.flatten(K.one_hot(K.cast(y_true, 'int32'), num_classes=4)[...,1:])
    y_pred_f = K.flatten(y_pred[...,1:])
    intersect = K.sum(y_true_f * y_pred_f, axis=-1)
    denom = K.sum(y_true_f + y_pred_f, axis=-1)
    return K.mean((2. * intersect / (denom + smooth)))

@tf.keras.utils.register_keras_serializable()
def dice_coef_loss(y_true, y_pred):
    '''
    Dice loss to minimize. Pass to model as loss during compile statement
    '''
    return 1 - dice_coef(y_true, y_pred)

# %%
@tf.keras.utils.register_keras_serializable()
def mean_iou(y_true, y_pred, smooth=1e-7):

    # Convert predictions from probabilities to labels
    y_pred = tf.argmax(y_pred, axis=-1)

    # Remove last dimension from ground truth
    y_true = tf.squeeze(y_true, axis=-1)

    # Convert to int32
    y_true = tf.cast(y_true, tf.int32)
    y_pred = tf.cast(y_pred, tf.int32)

    iou_scores = []

    # Ignore background class (0)
    for class_id in range(1, 4):

        true_class = tf.equal(y_true, class_id)
        pred_class = tf.equal(y_pred, class_id)

        intersection = tf.reduce_sum(
            tf.cast(true_class & pred_class, tf.float32)
        )

        union = tf.reduce_sum(
            tf.cast(true_class | pred_class, tf.float32)
        )

        iou = (intersection + smooth) / (union + smooth)

        iou_scores.append(iou)

    return tf.reduce_mean(iou_scores)

# %%
@tf.keras.utils.register_keras_serializable()
def dice_crossentropy(y_true, y_pred):

    dice = dice_coef_loss(y_true, y_pred)

    ce = tf.keras.losses.sparse_categorical_crossentropy(
        y_true,
        y_pred
    )

    return dice + ce

# %% [markdown]
# # Define the U-Net model architecture

# %%
def conv_block(input_tensor, num_filters):

    x = Conv2D(num_filters, (3, 3), padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filters, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    return x

def encoder_block(x, num_filters):
    x = conv_block(x, num_filters)
    p = MaxPooling2D((2, 2),strides=(2,2))(x)
    return x, p



def attention_gate(gating_signal, skip_connection, filters):

    theta_x = Conv2D(filters, (1,1), padding='same')(skip_connection)
    phi_g = Conv2D(filters, (1,1), padding='same')(gating_signal)
    add_xg = add([theta_x, phi_g])
    add_xg = Activation('relu')(add_xg)
    psi = Conv2D(1, (1,1), padding='same')(add_xg)
    psi = Activation('sigmoid')(psi)
    attention = multiply([skip_connection, psi])

    return attention


def decoder_block(input_tensor, skip_tensor, num_filters):

    decoder = Conv2DTranspose( num_filters,(2,2),strides=(2,2),padding='same')(input_tensor)
    skip_tensor = attention_gate(decoder,skip_tensor,num_filters )
    decoder = concatenate([decoder, skip_tensor])
    decoder = conv_block(decoder, num_filters)

    return decoder


def get_attention_unet(Kernels,IMG_HEIGHT=128, IMG_WIDTH=128, IMG_CHANNELS=4,N_CLASSES=4):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))


    encoder1, encoder_pool1 = encoder_block(inputs, Kernels)
    encoder2, encoder_pool2 = encoder_block(encoder_pool1, Kernels*2)
    encoder3, encoder_pool3 = encoder_block(encoder_pool2, Kernels*4)
    encoder4, encoder_pool4 = encoder_block(encoder_pool3, Kernels*8)


    center = conv_block(encoder_pool4,Kernels*16)


    decoder3 = decoder_block(center, encoder4, Kernels * 8)
    decoder2 = decoder_block(decoder3, encoder3, Kernels * 4)
    decoder1 = decoder_block(decoder2, encoder2, Kernels * 2)
    decoder0 = decoder_block(decoder1, encoder1, Kernels)


    outputs = Conv2D(N_CLASSES,(1, 1),activation='softmax')(decoder0)


    model = Model(inputs=[inputs],outputs=[outputs])

    model.compile(
        optimizer='adam',
        loss= dice_crossentropy,
        metrics=[dice_coef,mean_iou]

    )

    return model

# %%
model = get_attention_unet(16)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        592 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │      2,320 │ activation[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │      9,248 │ activation_2[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │     36,928 │ activation_4[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │    147,584 │ activation_6[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 128) │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8, 256) │    295,168 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8, 256) │    590,080 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │    131,200 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │     16,512 │ activation_7[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │     16,512 │ conv2d_transpose… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16, 16,    │          0 │ conv2d_10[0][0],  │
# │                     │ 128)              │            │ conv2d_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 16, 16,    │          0 │ add[0][0]         │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 16, 16, 1) │        129 │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 16, 16, 1) │          0 │ conv2d_12[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 16, 16,    │          0 │ activation_7[0][… │
# │                     │ 128)              │            │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 16, 16,    │    295,040 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 16, 16,    │    147,584 │ activation_12[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │     32,832 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 32, 32,    │      4,160 │ activation_5[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 32, 32,    │      4,160 │ conv2d_transpose… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 32, 32,    │          0 │ conv2d_15[0][0],  │
# │                     │ 64)               │            │ conv2d_16[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 32, 32,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 32, 32, 1) │         65 │ activation_14[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 32, 32, 1) │          0 │ conv2d_17[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 32, 32,    │          0 │ activation_5[0][… │
# │ (Multiply)          │ 64)               │            │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 32, 32,    │     73,792 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 32, 32,    │     36,928 │ activation_16[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │      8,224 │ activation_17[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 64, 64,    │      1,056 │ activation_3[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 64, 64,    │      1,056 │ conv2d_transpose… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 64, 64,    │          0 │ conv2d_20[0][0],  │
# │                     │ 32)               │            │ conv2d_21[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 64, 64,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 64, 64, 1) │         33 │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 64, 64, 1) │          0 │ conv2d_22[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 64, 64,    │          0 │ activation_3[0][… │
# │ (Multiply)          │ 32)               │            │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 64, 64,    │     18,464 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 64, 64,    │      9,248 │ activation_20[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │      2,064 │ activation_21[0]… │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 128, 128,  │        272 │ activation_1[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 128, 128,  │        272 │ conv2d_transpose… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 128, 128,  │          0 │ conv2d_25[0][0],  │
# │                     │ 16)               │            │ conv2d_26[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 128, 128,  │          0 │ add_3[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 128, 128,  │         17 │ activation_22[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 128, 128,  │          0 │ conv2d_27[0][0]   │
# │ (Activation)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │ (Multiply)          │ 16)               │            │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 128, 128,  │      4,624 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 128, 128,  │      2,320 │ activation_24[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 128, 128,  │         68 │ activation_25[0]… │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,991,432 (7.60 MB)
#  Trainable params: 1,988,488 (7.59 MB)
#  Non-trainable params: 2,944 (11.50 KB)

# %% [markdown]
# ## Cross Valitation

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=2,shuffle=True,random_state=42)

filter_options = [16,32]


best_mean_dice = -1

best_filters = None

for filters in filter_options:

    fold_no = 1

    train_dice_scores,train_Iou_scores,val_dice_scores = [],[],[]
    val_Iou_scores,train_loss,val_loss = [],[],[]


    for train_idx, val_idx in kf.split(train_patients):

        print(f"\n========== FOLD {fold_no} ==========")

        # ======================================
        # PATIENT SPLIT
        # ======================================

        fold_train_patients = [train_patients[i] for i in train_idx]

        fold_val_patients = [train_patients[i] for i in val_idx]

        # ======================================
        # IMAGE/MASK LISTS
        # ======================================

        fold_train_images = []
        fold_train_masks = []

        fold_val_images = []
        fold_val_masks = []

        for img_name, mask_name in zip(images_list,masks_list):

            patient_id = "_".join(img_name.split("_")[:2])

            if patient_id in fold_train_patients:

                fold_train_images.append(img_name)
                fold_train_masks.append(mask_name)

            elif patient_id in fold_val_patients:

                fold_val_images.append(img_name)
                fold_val_masks.append(mask_name)


        fold_train_generator = BrainTumorGenerator(
            fold_train_images,
            fold_train_masks,
            IMAGES_DIR,
            MASKS_DIR,
            batch_size=16,
            shuffle=True
        )

        fold_val_generator = BrainTumorGenerator(
            fold_val_images,
            fold_val_masks,
            IMAGES_DIR,
            MASKS_DIR,
            batch_size=16,
            shuffle=False
        )

        # ======================================
        # MODEL
        # ======================================

        model = get_attention_unet(filters)


        # ======================================
        # CALLBACKS
        # ======================================

        earlystopper = EarlyStopping(
            monitor='val_dice_coef',
            mode='max',
            patience=5,
            verbose=1,
            restore_best_weights=True)


        reduce_lr = ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=3,
            min_lr=1e-7,
            verbose=1)

        # ======================================
        # TRAIN
        # ======================================

        history = model.fit(
            fold_train_generator,
            validation_data=fold_val_generator,
            epochs=4,
            callbacks=[
                earlystopper,
                reduce_lr
            ]
        )

        # ======================================
        # EVALUATE
        # ======================================

        scores_train = model.evaluate(fold_train_generator )
        scores_val = model.evaluate(fold_val_generator)

        train_loss.append(scores_train[0])
        train_dice_scores.append(scores_train[1])
        current_dice = scores_val[1]
        train_Iou_scores.append(scores_train[2])

        val_loss.append(scores_val[0])
        val_dice_scores.append(scores_val[1])
        val_Iou_scores.append(scores_val[2])


        fold_no += 1

    mean_dice = np.mean(val_dice_scores)

    if mean_dice > best_mean_dice:
      best_mean_dice = mean_dice
      best_filters = filters
# Out:
# ========== FOLD 1 ==========
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 149s 91ms/step - dice_coef: 0.5282 - loss: 0.6512 - mean_iou: 0.4770 - val_dice_coef: 0.6512 - val_loss: 0.4064 - val_mean_iou: 0.5032 - learning_rate: 0.0010
# Epoch 2/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 80s 67ms/step - dice_coef: 0.7962 - loss: 0.2374 - mean_iou: 0.6697 - val_dice_coef: 0.7461 - val_loss: 0.2940 - val_mean_iou: 0.5801 - learning_rate: 0.0010
# Epoch 3/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 79s 67ms/step - dice_coef: 0.8248 - loss: 0.2042 - mean_iou: 0.7081 - val_dice_coef: 0.7623 - val_loss: 0.2787 - val_mean_iou: 0.6090 - learning_rate: 0.0010
# Epoch 4/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 82s 69ms/step - dice_coef: 0.8389 - loss: 0.1878 - mean_iou: 0.7281 - val_dice_coef: 0.7786 - val_loss: 0.2572 - val_mean_iou: 0.6047 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 4.
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - dice_coef: 0.8442 - loss: 0.1818 - mean_iou: 0.7228
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 19s 17ms/step - dice_coef: 0.7786 - loss: 0.2572 - mean_iou: 0.6047
#
# ========== FOLD 2 ==========
# Epoch 1/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 134s 90ms/step - dice_coef: 0.5457 - loss: 0.5987 - mean_iou: 0.4562 - val_dice_coef: 0.7065 - val_loss: 0.3378 - val_mean_iou: 0.5444 - learning_rate: 0.0010
# Epoch 2/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 79s 68ms/step - dice_coef: 0.7961 - loss: 0.2367 - mean_iou: 0.6623 - val_dice_coef: 0.6760 - val_loss: 0.3713 - val_mean_iou: 0.4855 - learning_rate: 0.0010
# Epoch 3/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 83s 69ms/step - dice_coef: 0.8246 - loss: 0.2040 - mean_iou: 0.7004 - val_dice_coef: 0.7215 - val_loss: 0.3229 - val_mean_iou: 0.5638 - learning_rate: 0.0010
# Epoch 4/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 79s 68ms/step - dice_coef: 0.8422 - loss: 0.1837 - mean_iou: 0.7265 - val_dice_coef: 0.7647 - val_loss: 0.2756 - val_mean_iou: 0.6219 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 4.
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - dice_coef: 0.8480 - loss: 0.1771 - mean_iou: 0.7362
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 19s 16ms/step - dice_coef: 0.7647 - loss: 0.2756 - mean_iou: 0.6219
#
# ========== FOLD 1 ==========
# Epoch 1/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 240s 166ms/step - dice_coef: 0.6538 - loss: 0.4041 - mean_iou: 0.5148 - val_dice_coef: 0.5952 - val_loss: 0.4734 - val_mean_iou: 0.3928 - learning_rate: 0.0010
# Epoch 2/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 166s 140ms/step - dice_coef: 0.7995 - loss: 0.2327 - mean_iou: 0.6679 - val_dice_coef: 0.7557 - val_loss: 0.2837 - val_mean_iou: 0.5934 - learning_rate: 0.0010
# Epoch 3/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 166s 140ms/step - dice_coef: 0.8287 - loss: 0.1989 - mean_iou: 0.7100 - val_dice_coef: 0.7519 - val_loss: 0.2865 - val_mean_iou: 0.5864 - learning_rate: 0.0010
# Epoch 4/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 166s 140ms/step - dice_coef: 0.8421 - loss: 0.1834 - mean_iou: 0.7307 - val_dice_coef: 0.7695 - val_loss: 0.2690 - val_mean_iou: 0.6136 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 4.
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 41s 34ms/step - dice_coef: 0.8476 - loss: 0.1770 - mean_iou: 0.7427
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 38s 33ms/step - dice_coef: 0.7695 - loss: 0.2690 - mean_iou: 0.6136
#
# ========== FOLD 2 ==========
# Epoch 1/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 223s 167ms/step - dice_coef: 0.6238 - loss: 0.4678 - mean_iou: 0.5088 - val_dice_coef: 0.6654 - val_loss: 0.3920 - val_mean_iou: 0.5415 - learning_rate: 0.0010
# Epoch 2/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 163s 141ms/step - dice_coef: 0.8047 - loss: 0.2273 - mean_iou: 0.6755 - val_dice_coef: 0.7002 - val_loss: 0.3478 - val_mean_iou: 0.5707 - learning_rate: 0.0010
# Epoch 3/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 163s 140ms/step - dice_coef: 0.8299 - loss: 0.1980 - mean_iou: 0.7102 - val_dice_coef: 0.7307 - val_loss: 0.3174 - val_mean_iou: 0.5905 - learning_rate: 0.0010
# Epoch 4/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 163s 141ms/step - dice_coef: 0.8485 - loss: 0.1764 - mean_iou: 0.7380 - val_dice_coef: 0.7836 - val_loss: 0.2552 - val_mean_iou: 0.6302 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 4.
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 40s 35ms/step - dice_coef: 0.8634 - loss: 0.1592 - mean_iou: 0.7563
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 39s 33ms/step - dice_coef: 0.7836 - loss: 0.2552 - mean_iou: 0.6302

# %%
print("Best Mean Dice Score:", best_mean_dice)
print("Best Number of Filters:", best_filters)
# Out:
# Best Mean Dice Score: 0.7765162587165833
# Best Number of Filters: 32

# %% [markdown]
# # Define training callbacks for early stopping, model checkpointing, learning rate reduction, and training logging

# %%
earlystopper = EarlyStopping(
    monitor='val_dice_coef',
    mode='max',
    patience=5,
    verbose=1,
    restore_best_weights=True
)

checkpointer = ModelCheckpoint(
    'model-best.keras',
    verbose=1,
    save_best_only=True,
    monitor='val_dice_coef',
    mode='max'
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-7,
    verbose=1
)

csv_logger = CSVLogger('training_log.csv')

# %% [markdown]
# # Train the U-Net model using the training and validation generators

# %%
model=get_attention_unet(16)

modeltrain = model.fit(
    final_train_generator,
    validation_data=final_val_generator,
    epochs=30,
    callbacks=[
        earlystopper,
        checkpointer,
        reduce_lr
    ]
)
# Out:
# Epoch 1/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - dice_coef: 0.5458 - loss: 0.5631 - mean_iou: 0.4663
# Epoch 1: val_dice_coef improved from None to 0.77342, saving model to model-best.keras
#
# Epoch 1: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 182s 66ms/step - dice_coef: 0.7054 - loss: 0.3480 - mean_iou: 0.5844 - val_dice_coef: 0.7734 - val_loss: 0.2615 - val_mean_iou: 0.6383 - learning_rate: 0.0010
# Epoch 2/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.8136 - loss: 0.2175 - mean_iou: 0.6871
# Epoch 2: val_dice_coef improved from 0.77342 to 0.78671, saving model to model-best.keras
#
# Epoch 2: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 126s 54ms/step - dice_coef: 0.8201 - loss: 0.2099 - mean_iou: 0.6960 - val_dice_coef: 0.7867 - val_loss: 0.2441 - val_mean_iou: 0.6228 - learning_rate: 0.0010
# Epoch 3/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.8386 - loss: 0.1882 - mean_iou: 0.7242
# Epoch 3: val_dice_coef improved from 0.78671 to 0.80994, saving model to model-best.keras
#
# Epoch 3: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 126s 54ms/step - dice_coef: 0.8421 - loss: 0.1841 - mean_iou: 0.7283 - val_dice_coef: 0.8099 - val_loss: 0.2181 - val_mean_iou: 0.6576 - learning_rate: 0.0010
# Epoch 4/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.8551 - loss: 0.1689 - mean_iou: 0.7477
# Epoch 4: val_dice_coef did not improve from 0.80994
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 125s 53ms/step - dice_coef: 0.8574 - loss: 0.1662 - mean_iou: 0.7503 - val_dice_coef: 0.8034 - val_loss: 0.2281 - val_mean_iou: 0.6309 - learning_rate: 0.0010
# Epoch 5/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.8653 - loss: 0.1569 - mean_iou: 0.7628
# Epoch 5: val_dice_coef improved from 0.80994 to 0.81389, saving model to model-best.keras
#
# Epoch 5: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 126s 54ms/step - dice_coef: 0.8676 - loss: 0.1542 - mean_iou: 0.7662 - val_dice_coef: 0.8139 - val_loss: 0.2155 - val_mean_iou: 0.6721 - learning_rate: 0.0010
# Epoch 6/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.8742 - loss: 0.1464 - mean_iou: 0.7760
# Epoch 6: val_dice_coef improved from 0.81389 to 0.81813, saving model to model-best.keras
#
# Epoch 6: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 125s 53ms/step - dice_coef: 0.8748 - loss: 0.1457 - mean_iou: 0.7770 - val_dice_coef: 0.8181 - val_loss: 0.2134 - val_mean_iou: 0.6744 - learning_rate: 0.0010
# Epoch 7/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.8799 - loss: 0.1397 - mean_iou: 0.7848
# Epoch 7: val_dice_coef improved from 0.81813 to 0.82321, saving model to model-best.keras
#
# Epoch 7: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 125s 53ms/step - dice_coef: 0.8816 - loss: 0.1378 - mean_iou: 0.7875 - val_dice_coef: 0.8232 - val_loss: 0.2067 - val_mean_iou: 0.6954 - learning_rate: 0.0010
# Epoch 8/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.8886 - loss: 0.1295 - mean_iou: 0.7986
# Epoch 8: val_dice_coef improved from 0.82321 to 0.83021, saving model to model-best.keras
#
# Epoch 8: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 125s 53ms/step - dice_coef: 0.8876 - loss: 0.1306 - mean_iou: 0.7967 - val_dice_coef: 0.8302 - val_loss: 0.1978 - val_mean_iou: 0.6859 - learning_rate: 0.0010
# Epoch 9/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.8926 - loss: 0.1249 - mean_iou: 0.8060
# Epoch 9: val_dice_coef did not improve from 0.83021
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 125s 53ms/step - dice_coef: 0.8928 - loss: 0.1247 - mean_iou: 0.8054 - val_dice_coef: 0.8201 - val_loss: 0.2115 - val_mean_iou: 0.6739 - learning_rate: 0.0010
# Epoch 10/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.8967 - loss: 0.1201 - mean_iou: 0.8112
# Epoch 10: val_dice_coef did not improve from 0.83021
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 125s 53ms/step - dice_coef: 0.8964 - loss: 0.1204 - mean_iou: 0.8111 - val_dice_coef: 0.8147 - val_loss: 0.2159 - val_mean_iou: 0.6758 - learning_rate: 0.0010
# Epoch 11/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.9000 - loss: 0.1162 - mean_iou: 0.8174
# Epoch 11: val_dice_coef did not improve from 0.83021
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 124s 53ms/step - dice_coef: 0.9006 - loss: 0.1156 - mean_iou: 0.8181 - val_dice_coef: 0.8213 - val_loss: 0.2115 - val_mean_iou: 0.6852 - learning_rate: 0.0010
# Epoch 12/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - dice_coef: 0.9099 - loss: 0.1047 - mean_iou: 0.8342
# Epoch 12: val_dice_coef improved from 0.83021 to 0.83234, saving model to model-best.keras
#
# Epoch 12: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 127s 54ms/step - dice_coef: 0.9100 - loss: 0.1046 - mean_iou: 0.8340 - val_dice_coef: 0.8323 - val_loss: 0.1983 - val_mean_iou: 0.6858 - learning_rate: 5.0000e-04
# Epoch 13/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - dice_coef: 0.9122 - loss: 0.1020 - mean_iou: 0.8368
# Epoch 13: val_dice_coef improved from 0.83234 to 0.83493, saving model to model-best.keras
#
# Epoch 13: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 127s 54ms/step - dice_coef: 0.9129 - loss: 0.1012 - mean_iou: 0.8385 - val_dice_coef: 0.8349 - val_loss: 0.1963 - val_mean_iou: 0.6830 - learning_rate: 5.0000e-04
# Epoch 14/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.9148 - loss: 0.0990 - mean_iou: 0.8406
# Epoch 14: val_dice_coef did not improve from 0.83493
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 123s 53ms/step - dice_coef: 0.9152 - loss: 0.0986 - mean_iou: 0.8424 - val_dice_coef: 0.8278 - val_loss: 0.2049 - val_mean_iou: 0.6766 - learning_rate: 5.0000e-04
# Epoch 15/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.9172 - loss: 0.0963 - mean_iou: 0.8463
# Epoch 15: val_dice_coef did not improve from 0.83493
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 123s 52ms/step - dice_coef: 0.9171 - loss: 0.0963 - mean_iou: 0.8455 - val_dice_coef: 0.8314 - val_loss: 0.2016 - val_mean_iou: 0.6912 - learning_rate: 5.0000e-04
# Epoch 16/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.9186 - loss: 0.0946 - mean_iou: 0.8472
# Epoch 16: val_dice_coef did not improve from 0.83493
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 123s 52ms/step - dice_coef: 0.9185 - loss: 0.0947 - mean_iou: 0.8479 - val_dice_coef: 0.8284 - val_loss: 0.2051 - val_mean_iou: 0.6918 - learning_rate: 5.0000e-04
# Epoch 17/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.9231 - loss: 0.0894 - mean_iou: 0.8560
# Epoch 17: val_dice_coef did not improve from 0.83493
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 125s 53ms/step - dice_coef: 0.9232 - loss: 0.0893 - mean_iou: 0.8560 - val_dice_coef: 0.8333 - val_loss: 0.1996 - val_mean_iou: 0.6816 - learning_rate: 2.5000e-04
# Epoch 18/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - dice_coef: 0.9250 - loss: 0.0873 - mean_iou: 0.8591
# Epoch 18: val_dice_coef improved from 0.83493 to 0.83690, saving model to model-best.keras
#
# Epoch 18: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 127s 54ms/step - dice_coef: 0.9245 - loss: 0.0878 - mean_iou: 0.8583 - val_dice_coef: 0.8369 - val_loss: 0.1960 - val_mean_iou: 0.6918 - learning_rate: 2.5000e-04
# Epoch 19/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.9255 - loss: 0.0867 - mean_iou: 0.8604
# Epoch 19: val_dice_coef did not improve from 0.83690
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 124s 53ms/step - dice_coef: 0.9255 - loss: 0.0867 - mean_iou: 0.8601 - val_dice_coef: 0.8320 - val_loss: 0.2022 - val_mean_iou: 0.6875 - learning_rate: 2.5000e-04
# Epoch 20/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - dice_coef: 0.9264 - loss: 0.0857 - mean_iou: 0.8619
# Epoch 20: val_dice_coef did not improve from 0.83690
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 123s 53ms/step - dice_coef: 0.9265 - loss: 0.0856 - mean_iou: 0.8616 - val_dice_coef: 0.8341 - val_loss: 0.1992 - val_mean_iou: 0.6838 - learning_rate: 2.5000e-04
# Epoch 21/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.9269 - loss: 0.0850 - mean_iou: 0.8615
# Epoch 21: val_dice_coef did not improve from 0.83690
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 125s 53ms/step - dice_coef: 0.9272 - loss: 0.0847 - mean_iou: 0.8627 - val_dice_coef: 0.8310 - val_loss: 0.2044 - val_mean_iou: 0.6876 - learning_rate: 2.5000e-04
# Epoch 22/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.9285 - loss: 0.0831 - mean_iou: 0.8653
# Epoch 22: val_dice_coef did not improve from 0.83690
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 125s 53ms/step - dice_coef: 0.9295 - loss: 0.0821 - mean_iou: 0.8669 - val_dice_coef: 0.8346 - val_loss: 0.1997 - val_mean_iou: 0.6821 - learning_rate: 1.2500e-04
# Epoch 23/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dice_coef: 0.9298 - loss: 0.0818 - mean_iou: 0.8670
# Epoch 23: val_dice_coef did not improve from 0.83690
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 124s 53ms/step - dice_coef: 0.9301 - loss: 0.0814 - mean_iou: 0.8676 - val_dice_coef: 0.8358 - val_loss: 0.1983 - val_mean_iou: 0.6842 - learning_rate: 1.2500e-04
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 18.

# %% [markdown]
# # Evaluate the trained model on the test dataset and display performance metrics

# %%
best_epoch = np.argmax(modeltrain.history['val_dice_coef'])

print(f"Best Epoch: {best_epoch + 1}")

print(f"Train Loss: {modeltrain.history['loss'][best_epoch]:.4f}")
print(f"Validation Loss: {modeltrain.history['val_loss'][best_epoch]:.4f}")

print(f"Train Dice: {modeltrain.history['dice_coef'][best_epoch]:.4f}")
print(f"Validation Dice: {modeltrain.history['val_dice_coef'][best_epoch]:.4f}")
# Out:
# Best Epoch: 18
# Train Loss: 0.0878
# Validation Loss: 0.1960
# Train Dice: 0.9245
# Validation Dice: 0.8369

# %% [markdown]
# # Load the best saved model and evaluate its performance on the test dataset

# %%
best_model = load_model(
    'model-best.keras',
    custom_objects={
        'dice_coef': dice_coef
    }
)

# %%
resultstest = best_model.evaluate(test_generator)

for name, value in zip(best_model.metrics_names, resultstest ):
    print(f"{name}: {value:.4f}")
# Out:
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - dice_coef: 0.8251 - loss: 0.2087 - mean_iou: 0.6942
# loss: 0.2087
# compile_metrics: 0.8251

# %% [markdown]
# # Compute multi-class Dice scores and visualize MRI slices with ground truth and predicted tumor segmentations

# %%
def multiclass_dice_score(y_true, y_pred, num_classes=4, smooth=1e-6, include_background=True):
    dice_scores = []

    start_class = 0 if include_background else 1

    for class_id in range(start_class, num_classes):
        y_true_class = (y_true == class_id).astype(np.uint8)
        y_pred_class = (y_pred == class_id).astype(np.uint8)

        intersection = np.sum(y_true_class * y_pred_class)

        dice = (2.0 * intersection + smooth) / (
            np.sum(y_true_class) + np.sum(y_pred_class) + smooth
        )

        dice_scores.append(dice)

    return np.mean(dice_scores), dice_scores


def visualize_slice_80(model, patient_id, slice_num):
    image_name = f"{patient_id}_slice_{slice_num}.npy"

    img = np.load(os.path.join(IMAGES_DIR, image_name))
    img_input = img.astype(np.float32) / 255.0

    true_mask = np.load(os.path.join(MASKS_DIR, image_name)).astype(np.uint8)
    true_mask[true_mask == 4] = 3

    pred_mask = model.predict(
        np.expand_dims(img_input, axis=0),
        verbose=0
    )[0]

    pred_classes = np.argmax(pred_mask, axis=-1).astype(np.uint8)

    dice_mean, dice_per_class = multiclass_dice_score(
        true_mask,
        pred_classes,
        num_classes=4,
        include_background=False
    )

    print("True mask classes:", np.unique(true_mask))
    print("Predicted classes:", np.unique(pred_classes))

    print("Pixels clase 3 reales:",
          np.sum(true_mask == 3))

    print("Pixels clase 3 predichos:",
      np.sum(pred_classes == 3))

    fig, axes = plt.subplots(1, 4, figsize=(20, 5))

    axes[0].imshow(img[:, :, 0], cmap="gray")
    axes[0].imshow(true_mask, cmap="jet", alpha=0.5, vmin=0, vmax=4)
    axes[0].set_title("Overlay Original")
    axes[0].axis("off")

    axes[1].imshow(true_mask, cmap="jet", vmin=0, vmax=4)
    axes[1].set_title("Original Segmentation")
    axes[1].axis("off")

    axes[2].imshow(pred_classes, cmap="jet", vmin=0, vmax=4)
    axes[2].set_title("Predicted Segmentation")
    axes[2].axis("off")

    axes[3].imshow(img[:, :, 0], cmap="gray")
    axes[3].imshow(pred_classes, cmap="jet", alpha=0.5, vmin=0, vmax=4)
    axes[3].set_title(f"Overlay Prediction\nMean Dice: {dice_mean:.4f}")
    axes[3].axis("off")

    plt.tight_layout()
    plt.show()

    print(f"Mean Multiclass Dice: {dice_mean:.4f}")
    print(f"Dice clase 0: {dice_per_class[0]:.4f}")
    print(f"Dice clase 1: {dice_per_class[1]:.4f}")
    print(f"Dice clase 2: {dice_per_class[2]:.4f}")
    #print(f"Dice clase 3: {dice_per_class[3]:.4f}")

# %%
visualize_slice_80(model, "BraTS2021_00020",70)
# Out:
# True mask classes: [0 1 2 3]
# Predicted classes: [0 1 2 3]
# Pixels clase 3 reales: 140
# Pixels clase 3 predichos: 148
# Mean Multiclass Dice: 0.8975
# Dice clase 0: 0.9707
# Dice clase 1: 0.8189
# Dice clase 2: 0.9028
