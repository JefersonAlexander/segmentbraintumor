# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import kagglehub
import os
import shutil
import tarfile
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.layers import Dropout, Lambda
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau, CSVLogger
from tensorflow.keras import backend as K
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import load_model
from tensorflow.keras.metrics import Precision, Recall, MeanIoU

# %matplotlib inline
# %load_ext tensorboard

from sklearn.datasets import *

# %% [markdown]
# ## Mount Google Drive to access preprocessed datasets

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Check if a GPU is available for TensorFlow training

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
    print(f"SUCCESS: {len(gpus)} GPU(s) detected!")
    print(f"Device Name: {gpus[0].name}")
else:
    print(" ERROR: No GPU detected. You are running on CPU.")
# Out:
# SUCCESS: 1 GPU(s) detected!
# Device Name: /physical_device:GPU:0

# %% [markdown]
# ## Extract the preprocessed dataset from the ZIP file into the working directory

# %%
import zipfile
import os

# Path to the ZIP file containing the preprocessed dataset
zip_path = "/content/drive/MyDrive/segmentatioImage/processed_unet.zip"

# Directory where the dataset will be extracted
base_path = "/content/processed_unet"

# Create the destination folder if it does not exist
os.makedirs(base_path, exist_ok=True)

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(base_path)

print("Dataset extracted successfully")
# Out:
# Dataset extracted successfully

# %% [markdown]
# ## Display the files and folders extracted in the dataset directory

# %%
print(os.listdir(base_path))
# Out:
# ['images', 'masks']

# %%
IMAGES_DIR = os.path.join("/content/processed_unet/images")
MASKS_DIR = os.path.join("/content/processed_unet/masks")

# %% [markdown]
# ## Prepare and split the dataset into training, validation, and test sets based on patient IDs

# %%
# Split the dataset into training, validation, and test sets based on patient IDs
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import Sequence
import os
import numpy as np

# =========================
# 1. List image and mask files
# =========================

images_list = sorted(os.listdir(IMAGES_DIR))
masks_list = sorted(os.listdir(MASKS_DIR))

# Extract unique patient IDs
patient_ids = sorted(list(set([
    "_".join(img.split("_")[:2])
    for img in images_list
])))

print("Total patients:", len(patient_ids))


# =========================
# 2. Split patients into train, validation, and test sets
# =========================

train_patients, temp_patients = train_test_split(
    patient_ids,
    test_size=0.2,
    random_state=42
)

val_patients, test_patients = train_test_split(
    temp_patients,
    test_size=0.5,
    random_state=42
)

print("Train patients:", len(train_patients))
print("Validation patients:", len(val_patients))
print("Test patients:", len(test_patients))


# =========================
# 3. Create image and mask lists for each split
# =========================

train_images, train_masks = [], []
val_images, val_masks = [], []
test_images, test_masks = [], []

for img_name, mask_name in zip(images_list, masks_list):

    patient_id = "_".join(img_name.split("_")[:2])

    if patient_id in train_patients:
        train_images.append(img_name)
        train_masks.append(mask_name)

    elif patient_id in val_patients:
        val_images.append(img_name)
        val_masks.append(mask_name)

    elif patient_id in test_patients:
        test_images.append(img_name)
        test_masks.append(mask_name)

print("Train images:", len(train_images))
print("Validation images:", len(val_images))
print("Test images:", len(test_images))
# Out:
# Total patients: 800
# Train patients: 640
# Validation patients: 80
# Test patients: 80
# Train images: 37553
# Validation images: 4799
# Test images: 4715

# %% [markdown]
# ## Count the total number of images and segmentation masks in the dataset

# %%
num_images = len(os.listdir(IMAGES_DIR))
num_masks = len(os.listdir(MASKS_DIR))

print(f"Cantidad de imágenes: {num_images}")
print(f"Cantidad de máscaras: {num_masks}")
# Out:
# Cantidad de imágenes: 47067
# Cantidad de máscaras: 47067

# %% [markdown]
# ## Custom data generator for loading and preprocessing brain tumor MRI images and segmentation masks in batches

# %%
class BrainTumorGenerator(Sequence):

    def __init__(
        self,
        image_files,
        mask_files,
        images_dir,
        masks_dir,
        batch_size=16,
        shuffle=True
    ):
        self.image_files = image_files
        self.mask_files = mask_files
        self.images_dir = images_dir
        self.masks_dir = masks_dir
        self.batch_size = batch_size
        self.shuffle = shuffle

        self.indexes = np.arange(len(self.image_files))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.image_files) / self.batch_size))

    def __getitem__(self, index):

        batch_indexes = self.indexes[
            index * self.batch_size:(index + 1) * self.batch_size
        ]

        batch_images = []
        batch_masks = []

        for i in batch_indexes:

            img = np.load(
                os.path.join(self.images_dir, self.image_files[i])
            )

            mask = np.load(
                os.path.join(self.masks_dir, self.mask_files[i])
            )

            # images
            img = img.astype(np.float32) / 255.0

            # multiclass mask
            mask = mask.astype(np.uint8)
            mask[mask == 4] = 3

            # add chanel to the mask
            mask = np.expand_dims(mask, axis=-1)

            batch_images.append(img)
            batch_masks.append(mask)

        X = np.array(batch_images, dtype=np.float32)
        y = np.array(batch_masks, dtype=np.uint8)

        return X, y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %% [markdown]
# # Create data generators for training, validation, and testing datasets

# %%
final_train_generator = BrainTumorGenerator(
    train_images,
    train_masks,
    IMAGES_DIR,
    MASKS_DIR,
    batch_size=16,
    shuffle=True
)

final_val_generator = BrainTumorGenerator(
    val_images,
    val_masks,
    IMAGES_DIR,
    MASKS_DIR,
    batch_size=16,
    shuffle=False
)

test_generator = BrainTumorGenerator(
    test_images,
    test_masks,
    IMAGES_DIR,
    MASKS_DIR,
    batch_size=16,
    shuffle=False
)

# %% [markdown]
# # Define Dice coefficient metric and Dice loss function for multi-class image segmentation

# %%
@tf.keras.utils.register_keras_serializable()
def dice_coef(y_true, y_pred, smooth=1e-7):
    '''
    Dice coefficient for 10 categories. Ignores background pixel label 0
    Pass to model as metric during compile statement
    '''
    y_true_f = K.flatten(K.one_hot(K.cast(y_true, 'int32'), num_classes=4)[...,1:])
    y_pred_f = K.flatten(y_pred[...,1:])
    intersect = K.sum(y_true_f * y_pred_f, axis=-1)
    denom = K.sum(y_true_f + y_pred_f, axis=-1)
    return K.mean((2. * intersect / (denom + smooth)))

@tf.keras.utils.register_keras_serializable()
def dice_coef_loss(y_true, y_pred):
    '''
    Dice loss to minimize. Pass to model as loss during compile statement
    '''
    return 1 - dice_coef(y_true, y_pred)

# %%
@tf.keras.utils.register_keras_serializable()
def mean_iou(y_true, y_pred, smooth=1e-7):

    # Convert predictions from probabilities to labels
    y_pred = tf.argmax(y_pred, axis=-1)

    # Remove last dimension from ground truth
    y_true = tf.squeeze(y_true, axis=-1)

    # Convert to int32
    y_true = tf.cast(y_true, tf.int32)
    y_pred = tf.cast(y_pred, tf.int32)

    iou_scores = []

    # Ignore background class (0)
    for class_id in range(1, 4):

        true_class = tf.equal(y_true, class_id)
        pred_class = tf.equal(y_pred, class_id)

        intersection = tf.reduce_sum(
            tf.cast(true_class & pred_class, tf.float32)
        )

        union = tf.reduce_sum(
            tf.cast(true_class | pred_class, tf.float32)
        )

        iou = (intersection + smooth) / (union + smooth)

        iou_scores.append(iou)

    return tf.reduce_mean(iou_scores)

# %% [markdown]
# # Define the U-Net model architecture

# %%
def get_model_UNET(kernels,IMG_HEIGHT=128, IMG_WIDTH=128, IMG_CHANNELS=4, N_CLASSES=4):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))

    c1 = Conv2D(kernels, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(inputs)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(kernels, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(kernels*2, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(kernels*2, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(kernels*4, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(kernels*4, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(kernels*8, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(kernels*8, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D((2, 2))(c4)


    c5 = Conv2D(kernels*16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(kernels*16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c5)

    u6 = Conv2DTranspose(kernels*8, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])


    c6 = Conv2D(kernels*8, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(kernels*8, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = Conv2DTranspose(kernels*4, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(kernels*4, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(kernels*4, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = Conv2DTranspose(kernels*2, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(kernels*2, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(kernels*2, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = Conv2DTranspose(kernels, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(kernels, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(kernels, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(N_CLASSES, (1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    model.compile(
        optimizer='adam',
        loss= dice_coef_loss,
        metrics=[dice_coef,mean_iou]
    )

    return model

# %%
model = get_model_UNET(kernels=16)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        592 │ input_layer_1[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │      2,320 │ dropout[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │      9,248 │ dropout_1[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │     36,928 │ dropout_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │    147,584 │ dropout_3[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 128) │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8, 256) │    295,168 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 8, 8, 256) │          0 │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8, 256) │    590,080 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │    131,200 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │    295,040 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 16, 16,    │          0 │ conv2d_10[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │    147,584 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │     32,832 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │     73,792 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │     36,928 │ dropout_6[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │      8,224 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64,    │     18,464 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_14[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 64,    │      9,248 │ dropout_7[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │      2,064 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 128, 128,  │      4,624 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_16[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │      2,320 │ dropout_8[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 128, 128,  │         68 │ conv2d_17[0][0]   │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,941,300 (7.41 MB)
#  Trainable params: 1,941,300 (7.41 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Cross Valitation

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=2,shuffle=True,random_state=42)

filter_options = [16,32]


best_mean_dice = -1

best_filters = None

for filters in filter_options:

    fold_no = 1

    train_dice_scores,train_Iou_scores,val_dice_scores = [],[],[]
    val_Iou_scores,train_loss,val_loss = [],[],[]


    for train_idx, val_idx in kf.split(train_patients):

        print(f"\n========== FOLD {fold_no} ==========")

        # ======================================
        # PATIENT SPLIT
        # ======================================

        fold_train_patients = [train_patients[i] for i in train_idx]

        fold_val_patients = [train_patients[i] for i in val_idx]

        # ======================================
        # IMAGE/MASK LISTS
        # ======================================

        fold_train_images = []
        fold_train_masks = []

        fold_val_images = []
        fold_val_masks = []

        for img_name, mask_name in zip(images_list,masks_list):

            patient_id = "_".join(img_name.split("_")[:2])

            if patient_id in fold_train_patients:

                fold_train_images.append(img_name)
                fold_train_masks.append(mask_name)

            elif patient_id in fold_val_patients:

                fold_val_images.append(img_name)
                fold_val_masks.append(mask_name)


        fold_train_generator = BrainTumorGenerator(
            fold_train_images,
            fold_train_masks,
            IMAGES_DIR,
            MASKS_DIR,
            batch_size=16,
            shuffle=True
        )

        fold_val_generator = BrainTumorGenerator(
            fold_val_images,
            fold_val_masks,
            IMAGES_DIR,
            MASKS_DIR,
            batch_size=16,
            shuffle=False
        )

        # ======================================
        # MODEL
        # ======================================

        model = get_model_UNET(filters)


        # ======================================
        # CALLBACKS
        # ======================================

        earlystopper = EarlyStopping(
            monitor='val_dice_coef',
            mode='max',
            patience=5,
            verbose=1,
            restore_best_weights=True)


        reduce_lr = ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=3,
            min_lr=1e-7,
            verbose=1)

        # ======================================
        # TRAIN
        # ======================================

        history = model.fit(
            fold_train_generator,
            validation_data=fold_val_generator,
            epochs=4,
            callbacks=[
                earlystopper,
                reduce_lr
            ]
        )

        # ======================================
        # EVALUATE
        # ======================================

        scores_train = model.evaluate(fold_train_generator )
        scores_val = model.evaluate(fold_val_generator)

        train_loss.append(scores_train[0])
        train_dice_scores.append(scores_train[1])
        current_dice = scores_val[1]
        train_Iou_scores.append(scores_train[2])

        val_loss.append(scores_val[0])
        val_dice_scores.append(scores_val[1])
        val_Iou_scores.append(scores_val[2])


        fold_no += 1

    mean_dice = np.mean(val_dice_scores)

    if mean_dice > best_mean_dice:
      best_mean_dice = mean_dice
      best_filters = filters
# Out:
# ========== FOLD 1 ==========
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 112s 73ms/step - dice_coef: 0.4839 - loss: 0.5163 - mean_iou: 0.1991 - val_dice_coef: 0.6201 - val_loss: 0.3799 - val_mean_iou: 0.4037 - learning_rate: 0.0010
# Epoch 2/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 61s 52ms/step - dice_coef: 0.7446 - loss: 0.2552 - mean_iou: 0.5736 - val_dice_coef: 0.7398 - val_loss: 0.2601 - val_mean_iou: 0.5480 - learning_rate: 0.0010
# Epoch 3/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 62s 52ms/step - dice_coef: 0.8041 - loss: 0.1960 - mean_iou: 0.6641 - val_dice_coef: 0.7582 - val_loss: 0.2418 - val_mean_iou: 0.5775 - learning_rate: 0.0010
# Epoch 4/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 63s 53ms/step - dice_coef: 0.8277 - loss: 0.1724 - mean_iou: 0.7000 - val_dice_coef: 0.7628 - val_loss: 0.2372 - val_mean_iou: 0.5900 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 4.
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - dice_coef: 0.8422 - loss: 0.1578 - mean_iou: 0.7207
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 16s 14ms/step - dice_coef: 0.7628 - loss: 0.2372 - mean_iou: 0.5900
#
# ========== FOLD 2 ==========
# Epoch 1/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 100s 71ms/step - dice_coef: 0.5029 - loss: 0.4971 - mean_iou: 0.1648 - val_dice_coef: 0.5164 - val_loss: 0.4835 - val_mean_iou: 0.2661 - learning_rate: 0.0010
# Epoch 2/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 109s 52ms/step - dice_coef: 0.6259 - loss: 0.3741 - mean_iou: 0.3253 - val_dice_coef: 0.6667 - val_loss: 0.3333 - val_mean_iou: 0.4481 - learning_rate: 0.0010
# Epoch 3/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 62s 53ms/step - dice_coef: 0.7906 - loss: 0.2094 - mean_iou: 0.6340 - val_dice_coef: 0.7438 - val_loss: 0.2561 - val_mean_iou: 0.5675 - learning_rate: 0.0010
# Epoch 4/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 63s 54ms/step - dice_coef: 0.8287 - loss: 0.1713 - mean_iou: 0.6925 - val_dice_coef: 0.7588 - val_loss: 0.2410 - val_mean_iou: 0.6013 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 4.
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 17s 15ms/step - dice_coef: 0.8463 - loss: 0.1537 - mean_iou: 0.7217
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - dice_coef: 0.7588 - loss: 0.2410 - mean_iou: 0.6013
#
# ========== FOLD 1 ==========
# Epoch 1/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 184s 130ms/step - dice_coef: 3.4598e-04 - loss: 0.9997 - mean_iou: 8.5431e-05 - val_dice_coef: 0.0000e+00 - val_loss: 1.0000 - val_mean_iou: 0.1027 - learning_rate: 0.0010
# Epoch 2/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 130s 110ms/step - dice_coef: 0.0000e+00 - loss: 1.0000 - mean_iou: 7.1026e-11 - val_dice_coef: 0.0000e+00 - val_loss: 1.0000 - val_mean_iou: 0.1027 - learning_rate: 0.0010
# Epoch 3/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 130s 109ms/step - dice_coef: 0.0000e+00 - loss: 1.0000 - mean_iou: 6.5770e-11 - val_dice_coef: 0.0000e+00 - val_loss: 1.0000 - val_mean_iou: 0.1027 - learning_rate: 0.0010
# Epoch 4/4
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - dice_coef: 0.0000e+00 - loss: 1.0000 - mean_iou: 6.7800e-11
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 140s 118ms/step - dice_coef: 0.0000e+00 - loss: 1.0000 - mean_iou: 6.7331e-11 - val_dice_coef: 0.0000e+00 - val_loss: 1.0000 - val_mean_iou: 0.1027 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 1.
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 33s 27ms/step - dice_coef: 0.0000e+00 - loss: 1.0000 - mean_iou: 6.7476e-11
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 31s 27ms/step - dice_coef: 0.0000e+00 - loss: 1.0000 - mean_iou: 0.1027
#
# ========== FOLD 2 ==========
# Epoch 1/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 169s 130ms/step - dice_coef: 0.0319 - loss: 0.9681 - mean_iou: 0.0055 - val_dice_coef: 0.0312 - val_loss: 0.9688 - val_mean_iou: 0.1116 - learning_rate: 0.0010
# Epoch 2/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 128s 110ms/step - dice_coef: 0.0325 - loss: 0.9675 - mean_iou: 0.0056 - val_dice_coef: 0.0312 - val_loss: 0.9688 - val_mean_iou: 0.1116 - learning_rate: 0.0010
# Epoch 3/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 129s 111ms/step - dice_coef: 0.0325 - loss: 0.9675 - mean_iou: 0.0056 - val_dice_coef: 0.0312 - val_loss: 0.9688 - val_mean_iou: 0.1116 - learning_rate: 0.0010
# Epoch 4/4
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - dice_coef: 0.0322 - loss: 0.9678 - mean_iou: 0.0055
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 129s 111ms/step - dice_coef: 0.0325 - loss: 0.9675 - mean_iou: 0.0056 - val_dice_coef: 0.0312 - val_loss: 0.9688 - val_mean_iou: 0.1116 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 1.
# 1162/1162 ━━━━━━━━━━━━━━━━━━━━ 33s 28ms/step - dice_coef: 0.0325 - loss: 0.9675 - mean_iou: 0.0056
# 1186/1186 ━━━━━━━━━━━━━━━━━━━━ 32s 27ms/step - dice_coef: 0.0312 - loss: 0.9688 - mean_iou: 0.1116

# %%
print(best_filters)
# Out:
# 16

# %% [markdown]
# # Define training callbacks for early stopping, model checkpointing, learning rate reduction, and training logging

# %%
earlystopper = EarlyStopping(
    monitor='val_dice_coef',
    mode='max',
    patience=5,
    verbose=1,
    restore_best_weights=True
)

checkpointer = ModelCheckpoint(
    'model-best.keras',
    verbose=1,
    save_best_only=True,
    monitor='val_dice_coef',
    mode='max'
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-7,
    verbose=1
)

csv_logger = CSVLogger('training_log.csv')

# %% [markdown]
# # Train the U-Net model using the training and validation generators

# %%
model = get_model_UNET(best_filters)

modeltrain = model.fit(
    final_train_generator,
    validation_data=final_val_generator,
    epochs=30,
    callbacks=[
        earlystopper,
        checkpointer,
        reduce_lr
    ]
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dice_coef: 0.4463 - loss: 0.5537 - mean_iou: 0.1430
# Epoch 1: val_dice_coef improved from None to 0.72530, saving model to model-best.keras
#
# Epoch 1: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 129s 47ms/step - dice_coef: 0.5414 - loss: 0.4586 - mean_iou: 0.2242 - val_dice_coef: 0.7253 - val_loss: 0.2747 - val_mean_iou: 0.5089 - learning_rate: 0.0010
# Epoch 2/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.7662 - loss: 0.2338 - mean_iou: 0.5991
# Epoch 2: val_dice_coef improved from 0.72530 to 0.78275, saving model to model-best.keras
#
# Epoch 2: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.7847 - loss: 0.2153 - mean_iou: 0.6287 - val_dice_coef: 0.7828 - val_loss: 0.2173 - val_mean_iou: 0.6255 - learning_rate: 0.0010
# Epoch 3/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8134 - loss: 0.1867 - mean_iou: 0.6732
# Epoch 3: val_dice_coef improved from 0.78275 to 0.79853, saving model to model-best.keras
#
# Epoch 3: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8185 - loss: 0.1815 - mean_iou: 0.6811 - val_dice_coef: 0.7985 - val_loss: 0.2015 - val_mean_iou: 0.6317 - learning_rate: 0.0010
# Epoch 4/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - dice_coef: 0.8298 - loss: 0.1702 - mean_iou: 0.6993
# Epoch 4: val_dice_coef improved from 0.79853 to 0.81054, saving model to model-best.keras
#
# Epoch 4: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 102s 44ms/step - dice_coef: 0.8323 - loss: 0.1678 - mean_iou: 0.7033 - val_dice_coef: 0.8105 - val_loss: 0.1895 - val_mean_iou: 0.6430 - learning_rate: 0.0010
# Epoch 5/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8398 - loss: 0.1602 - mean_iou: 0.7150
# Epoch 5: val_dice_coef did not improve from 0.81054
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 99s 42ms/step - dice_coef: 0.8401 - loss: 0.1598 - mean_iou: 0.7158 - val_dice_coef: 0.8084 - val_loss: 0.1916 - val_mean_iou: 0.6497 - learning_rate: 0.0010
# Epoch 6/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8449 - loss: 0.1551 - mean_iou: 0.7216
# Epoch 6: val_dice_coef improved from 0.81054 to 0.81368, saving model to model-best.keras
#
# Epoch 6: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 99s 42ms/step - dice_coef: 0.8438 - loss: 0.1563 - mean_iou: 0.7209 - val_dice_coef: 0.8137 - val_loss: 0.1863 - val_mean_iou: 0.6410 - learning_rate: 0.0010
# Epoch 7/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8488 - loss: 0.1512 - mean_iou: 0.7290
# Epoch 7: val_dice_coef did not improve from 0.81368
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8490 - loss: 0.1510 - mean_iou: 0.7292 - val_dice_coef: 0.8125 - val_loss: 0.1875 - val_mean_iou: 0.6412 - learning_rate: 0.0010
# Epoch 8/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8490 - loss: 0.1510 - mean_iou: 0.7300
# Epoch 8: val_dice_coef did not improve from 0.81368
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8497 - loss: 0.1503 - mean_iou: 0.7305 - val_dice_coef: 0.8089 - val_loss: 0.1911 - val_mean_iou: 0.6414 - learning_rate: 0.0010
# Epoch 9/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8530 - loss: 0.1470 - mean_iou: 0.7357
# Epoch 9: val_dice_coef improved from 0.81368 to 0.81526, saving model to model-best.keras
#
# Epoch 9: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8519 - loss: 0.1481 - mean_iou: 0.7336 - val_dice_coef: 0.8153 - val_loss: 0.1848 - val_mean_iou: 0.6607 - learning_rate: 0.0010
# Epoch 10/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8520 - loss: 0.1480 - mean_iou: 0.7336
# Epoch 10: val_dice_coef did not improve from 0.81526
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 100s 42ms/step - dice_coef: 0.8497 - loss: 0.1503 - mean_iou: 0.7303 - val_dice_coef: 0.8093 - val_loss: 0.1907 - val_mean_iou: 0.6568 - learning_rate: 0.0010
# Epoch 11/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8518 - loss: 0.1482 - mean_iou: 0.7338
# Epoch 11: val_dice_coef did not improve from 0.81526
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8529 - loss: 0.1471 - mean_iou: 0.7351 - val_dice_coef: 0.8137 - val_loss: 0.1863 - val_mean_iou: 0.6659 - learning_rate: 0.0010
# Epoch 12/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8545 - loss: 0.1455 - mean_iou: 0.7380
# Epoch 12: val_dice_coef improved from 0.81526 to 0.81815, saving model to model-best.keras
#
# Epoch 12: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 99s 42ms/step - dice_coef: 0.8543 - loss: 0.1457 - mean_iou: 0.7372 - val_dice_coef: 0.8181 - val_loss: 0.1819 - val_mean_iou: 0.6644 - learning_rate: 0.0010
# Epoch 13/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8554 - loss: 0.1446 - mean_iou: 0.7399
# Epoch 13: val_dice_coef did not improve from 0.81815
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8550 - loss: 0.1451 - mean_iou: 0.7392 - val_dice_coef: 0.8147 - val_loss: 0.1853 - val_mean_iou: 0.6645 - learning_rate: 0.0010
# Epoch 14/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8561 - loss: 0.1439 - mean_iou: 0.7399
# Epoch 14: val_dice_coef did not improve from 0.81815
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8553 - loss: 0.1447 - mean_iou: 0.7392 - val_dice_coef: 0.8087 - val_loss: 0.1913 - val_mean_iou: 0.6601 - learning_rate: 0.0010
# Epoch 15/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8542 - loss: 0.1459 - mean_iou: 0.7387
# Epoch 15: val_dice_coef did not improve from 0.81815
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8552 - loss: 0.1448 - mean_iou: 0.7400 - val_dice_coef: 0.8134 - val_loss: 0.1866 - val_mean_iou: 0.6695 - learning_rate: 0.0010
# Epoch 16/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8635 - loss: 0.1365 - mean_iou: 0.7507
# Epoch 16: val_dice_coef improved from 0.81815 to 0.82563, saving model to model-best.keras
#
# Epoch 16: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8665 - loss: 0.1335 - mean_iou: 0.7562 - val_dice_coef: 0.8256 - val_loss: 0.1744 - val_mean_iou: 0.6659 - learning_rate: 5.0000e-04
# Epoch 17/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8699 - loss: 0.1301 - mean_iou: 0.7615
# Epoch 17: val_dice_coef improved from 0.82563 to 0.82675, saving model to model-best.keras
#
# Epoch 17: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8696 - loss: 0.1304 - mean_iou: 0.7613 - val_dice_coef: 0.8268 - val_loss: 0.1733 - val_mean_iou: 0.6832 - learning_rate: 5.0000e-04
# Epoch 18/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8496 - loss: 0.1504 - mean_iou: 0.7378
# Epoch 18: val_dice_coef did not improve from 0.82675
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8562 - loss: 0.1438 - mean_iou: 0.7451 - val_dice_coef: 0.8241 - val_loss: 0.1759 - val_mean_iou: 0.6800 - learning_rate: 5.0000e-04
# Epoch 19/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8717 - loss: 0.1283 - mean_iou: 0.7636
# Epoch 19: val_dice_coef did not improve from 0.82675
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8729 - loss: 0.1271 - mean_iou: 0.7656 - val_dice_coef: 0.8249 - val_loss: 0.1752 - val_mean_iou: 0.6723 - learning_rate: 5.0000e-04
# Epoch 20/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8723 - loss: 0.1276 - mean_iou: 0.7658
# Epoch 20: val_dice_coef did not improve from 0.82675
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8730 - loss: 0.1270 - mean_iou: 0.7662 - val_dice_coef: 0.8224 - val_loss: 0.1776 - val_mean_iou: 0.6769 - learning_rate: 5.0000e-04
# Epoch 21/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8777 - loss: 0.1223 - mean_iou: 0.7719
# Epoch 21: val_dice_coef improved from 0.82675 to 0.83183, saving model to model-best.keras
#
# Epoch 21: finished saving model to model-best.keras
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8785 - loss: 0.1215 - mean_iou: 0.7740 - val_dice_coef: 0.8318 - val_loss: 0.1682 - val_mean_iou: 0.6832 - learning_rate: 2.5000e-04
# Epoch 22/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8796 - loss: 0.1204 - mean_iou: 0.7757
# Epoch 22: val_dice_coef did not improve from 0.83183
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8799 - loss: 0.1199 - mean_iou: 0.7761 - val_dice_coef: 0.8285 - val_loss: 0.1716 - val_mean_iou: 0.6807 - learning_rate: 2.5000e-04
# Epoch 23/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8797 - loss: 0.1203 - mean_iou: 0.7758
# Epoch 23: val_dice_coef did not improve from 0.83183
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8804 - loss: 0.1196 - mean_iou: 0.7771 - val_dice_coef: 0.8287 - val_loss: 0.1713 - val_mean_iou: 0.6790 - learning_rate: 2.5000e-04
# Epoch 24/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8820 - loss: 0.1179 - mean_iou: 0.7800
# Epoch 24: val_dice_coef did not improve from 0.83183
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 98s 42ms/step - dice_coef: 0.8822 - loss: 0.1178 - mean_iou: 0.7799 - val_dice_coef: 0.8290 - val_loss: 0.1710 - val_mean_iou: 0.6779 - learning_rate: 2.5000e-04
# Epoch 25/30
# 2347/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8841 - loss: 0.1159 - mean_iou: 0.7825
# Epoch 25: val_dice_coef did not improve from 0.83183
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 97s 41ms/step - dice_coef: 0.8846 - loss: 0.1154 - mean_iou: 0.7837 - val_dice_coef: 0.8306 - val_loss: 0.1694 - val_mean_iou: 0.6889 - learning_rate: 1.2500e-04
# Epoch 26/30
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dice_coef: 0.8856 - loss: 0.1144 - mean_iou: 0.7857
# Epoch 26: val_dice_coef did not improve from 0.83183
# 2348/2348 ━━━━━━━━━━━━━━━━━━━━ 99s 42ms/step - dice_coef: 0.8854 - loss: 0.1145 - mean_iou: 0.7852 - val_dice_coef: 0.8298 - val_loss: 0.1702 - val_mean_iou: 0.6842 - learning_rate: 1.2500e-04
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 21.

# %% [markdown]
# # Evaluate the trained model on the test dataset and display performance metrics

# %%
best_epoch = np.argmax(modeltrain.history['val_dice_coef'])

print(f"Best Epoch: {best_epoch + 1}")

print(f"Train Loss: {modeltrain.history['loss'][best_epoch]:.4f}")
print(f"Validation Loss: {modeltrain.history['val_loss'][best_epoch]:.4f}")

print(f"Train Dice: {modeltrain.history['dice_coef'][best_epoch]:.4f}")
print(f"Validation Dice: {modeltrain.history['val_dice_coef'][best_epoch]:.4f}")
# Out:
# Best Epoch: 21
# Train Loss: 0.1215
# Validation Loss: 0.1682
# Train Dice: 0.8785
# Validation Dice: 0.8318

# %% [markdown]
# # Load the best saved model and evaluate its performance on the test dataset

# %%
best_model = load_model(
    'model-best.keras',
    custom_objects={
        'dice_coef': dice_coef
    }
)

# %%
resultstest = best_model.evaluate(test_generator)

for name, value in zip(best_model.metrics_names, resultstest ):
    print(f"{name}: {value:.4f}")
# Out:
# 295/295 ━━━━━━━━━━━━━━━━━━━━ 15s 44ms/step - dice_coef: 0.8225 - loss: 0.1776 - mean_iou: 0.6789
# loss: 0.1776
# compile_metrics: 0.8225

# %% [markdown]
# # Compute multi-class Dice scores and visualize MRI slices with ground truth and predicted tumor segmentations

# %%
def multiclass_dice_score(y_true, y_pred, num_classes=4, smooth=1e-6, include_background=True):
    dice_scores = []

    start_class = 0 if include_background else 1

    for class_id in range(start_class, num_classes):
        y_true_class = (y_true == class_id).astype(np.uint8)
        y_pred_class = (y_pred == class_id).astype(np.uint8)

        intersection = np.sum(y_true_class * y_pred_class)

        dice = (2.0 * intersection + smooth) / (
            np.sum(y_true_class) + np.sum(y_pred_class) + smooth
        )

        dice_scores.append(dice)

    return np.mean(dice_scores), dice_scores


def visualize_slice_80(model, patient_id, slice_num):
    image_name = f"{patient_id}_slice_{slice_num}.npy"

    img = np.load(os.path.join(IMAGES_DIR, image_name))
    img_input = img.astype(np.float32) / 255.0

    true_mask = np.load(os.path.join(MASKS_DIR, image_name)).astype(np.uint8)
    true_mask[true_mask == 4] = 3

    pred_mask = model.predict(
        np.expand_dims(img_input, axis=0),
        verbose=0
    )[0]

    pred_classes = np.argmax(pred_mask, axis=-1).astype(np.uint8)

    dice_mean, dice_per_class = multiclass_dice_score(
        true_mask,
        pred_classes,
        num_classes=4,
        include_background=False
    )

    print("True mask classes:", np.unique(true_mask))
    print("Predicted classes:", np.unique(pred_classes))

    print("Pixels clase 3 reales:",
          np.sum(true_mask == 3))

    print("Pixels clase 3 predichos:",
      np.sum(pred_classes == 3))

    fig, axes = plt.subplots(1, 4, figsize=(20, 5))

    axes[0].imshow(img[:, :, 0], cmap="gray")
    axes[0].imshow(true_mask, cmap="jet", alpha=0.5, vmin=0, vmax=4)
    axes[0].set_title("Overlay Original")
    axes[0].axis("off")

    axes[1].imshow(true_mask, cmap="jet", vmin=0, vmax=4)
    axes[1].set_title("Original Segmentation")
    axes[1].axis("off")

    axes[2].imshow(pred_classes, cmap="jet", vmin=0, vmax=4)
    axes[2].set_title("Predicted Segmentation")
    axes[2].axis("off")

    axes[3].imshow(img[:, :, 0], cmap="gray")
    axes[3].imshow(pred_classes, cmap="jet", alpha=0.5, vmin=0, vmax=4)
    axes[3].set_title(f"Overlay Prediction\nMean Dice: {dice_mean:.4f}")
    axes[3].axis("off")

    plt.tight_layout()
    plt.show()

    print(f"Mean Multiclass Dice: {dice_mean:.4f}")
    print(f"Dice clase 0: {dice_per_class[0]:.4f}")
    print(f"Dice clase 1: {dice_per_class[1]:.4f}")
    print(f"Dice clase 2: {dice_per_class[2]:.4f}")
    #print(f"Dice clase 3: {dice_per_class[3]:.4f}")

# %%
visualize_slice_80(model, "BraTS2021_00020",70)
# Out:
# True mask classes: [0 1 2 3]
# Predicted classes: [0 1 2 3]
# Pixels clase 3 reales: 140
# Pixels clase 3 predichos: 145
# Mean Multiclass Dice: 0.8595
# Dice clase 0: 0.9612
# Dice clase 1: 0.7472
# Dice clase 2: 0.8702
